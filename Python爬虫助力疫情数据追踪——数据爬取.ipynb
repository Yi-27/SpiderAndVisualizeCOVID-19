# %%
# 导入包
import pandas as pd
import requests
import json
import os
import time

# %%
# 定义一个存储DataFrame的函数，包装了to_csv()方法
def df_to_csv(df=None, filepath=None, filename=None, encoding='GBK', retain_index=False):
    """
    params:
        df：DataFrame数据
        filepath：文件存储路径
        filename：文件名
        encoding：文件存储编码格式
        retain_index：是否保留DataFrame的索引
    """
    if not os.path.exists(filepath): # 先判断这个文件夹是否已存在，已存在说明数据时最新的
        os.mkdir(filepath) # 创建时，文件夹名里有时间来区分数据是否为最新
    df.to_csv(filepath + '/' + filename, encoding=encoding, index=retain_index) # 保存到文件夹中

# %%
# 请求头 这里我尽量弄的全一点
headers = {
    'accept-encoding': 'gzip, deflate, br',
    'accept-language':'zh-CN,zh;q=0.9,en;q=0.8,en-GB;q=0.7,en-US;q=0.6',
    'cookie': 'pgv_pvid=7838988661; ptcz=a749c13713fc703b48592a49922470ed1eda1bcc7b68d2cf5be6fa79c731b76d; pgv_pvi=9718182912; RK=vkrweAJtMM; o_cookie=763074310; pac_uid=1_763074310; luin=o0763074310; lskey=000100007d08c463d9cc757cc4c5ae2cf3732897a65bf7de58e88b9524158f61b02e143bcf6124869366ea7d; tvfe_boss_uuid=e1c916f5e5e6e6bd; _txjk_whl_uuid_aa5wayli=58f307f1d8264ccb8aeb92b2f6225b14',
    'referer': 'https://news.qq.com/zt2020/page/feiyan.htm',
    'sec-fetch-dest': 'script',
    'sec-fetch-mode': 'no-cors',
    'sec-fetch-site': 'same-site',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.116 Safari/537.36 Edg/83.0.478.61'
}
# 由于网址不同需要的请求头也不太一样，故设置两个请求头，注意cookie是一段时间就会改变的，需要手动来改
headers2 = {
    'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9',
    'Accept-Encoding': 'gzip, deflate, br',
    'Accept-Language': 'zh-CN,zh;q=0.9,en;q=0.8,en-GB;q=0.7,en-US;q=0.6',
    'Cache-Control': 'max-age=0',
    'Connection': 'keep-alive',
    'Cookie': 'pgv_pvid=7838988661; ptcz=a749c13713fc703b48592a49922470ed1eda1bcc7b68d2cf5be6fa79c731b76d; pgv_pvi=9718182912; RK=vkrweAJtMM; o_cookie=763074310; pac_uid=1_763074310; luin=o0763074310; lskey=000100007d08c463d9cc757cc4c5ae2cf3732897a65bf7de58e88b9524158f61b02e143bcf6124869366ea7d; tvfe_boss_uuid=e1c916f5e5e6e6bd; _txjk_whl_uuid_aa5wayli=58f307f1d8264ccb8aeb92b2f6225b14; uin=o0763074310; skey=@xEkmEQkwn; qqmusic_uin=; qqmusic_key=; qqmusic_fromtag=; pgv_info=ssid=s1515695283',
    'Host': 'api.inews.qq.com',
    'Sec-Fetch-Dest': 'document',
    'Sec-Fetch-Mode': 'navigate',
    'Sec-Fetch-Site': 'none',
    'Sec-Fetch-User': '?1',
    'Upgrade-Insecure-Requests': '1',
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.116 Safari/537.36 Edg/83.0.478.61'
}

# %% [markdown]
# # 所需要的所有url

# %%
# 国内数据
url0 = "https://view.inews.qq.com/g2/getOnsInfo?name=disease_h5"
 # 国内数据（随时间变化）
url1 = "https://view.inews.qq.com/g2/getOnsInfo?name=disease_other"
# 外国数据（比率和排名）
url2 = "https://api.inews.qq.com/newsqa/v1/automation/modules/list?modules=FAutoCountryWeekCompRank,FAutoContinentConfirmStatis,FAutoConfirmMillionRankList,FAutoHealDeadRateRankList"
# 外国数据（排名）
url3 = "https://view.inews.qq.com/g2/getOnsInfo?name=disease_foreign"
# 全球总体数据（随时间变化）
url4 = "https://api.inews.qq.com/newsqa/v1/automation/modules/list?modules=FAutoGlobalStatis,FAutoContinentStatis,FAutoGlobalDailyList,FAutoCountryConfirmAdd"
# 外国数据（按国家或大洲查看）
url5 = "https://api.inews.qq.com/newsqa/v1/automation/foreign/country/ranklist"
# 外国部分国家历史每日数据（随时间变化）
url6 = "https://api.inews.qq.com/newsqa/v1/automation/foreign/daily/list?country="
# 国内具体省市每日数据
url7 = "https://api.inews.qq.com/newsqa/v1/query/pubished/daily/list?province="

# %% [markdown]
# # 国内数据

# %%
# url0 = 'https://view.inews.qq.com/g2/getOnsInfo?name=disease_h5
res0 = requests.get(url0, headers=headers) # 请求数据，使用第一种请求头
data0 = json.loads(res0.json()['data']) # 因为data对应的值还是json字符串，还要转成Python字典

# %%
# 国内数据存储路径
filepath_cn = "./疫情数据/国内数据"
if not os.path.exists(filepath_cn): # 先判断这个文件夹是否已存在，已存在说明数据时最新的
    os.mkdir(filepath_cn) # 创建用最后更新时间来创建文件夹

china_data = {'name': data0['areaTree'][0]['name']} # 新建一个字典，并地区名添加进去
china_data.update(data0['areaTree'][0]['total']) # 合并地区的数据，字典合并字典
provinces_data =  [china_data] # 先创建省份数据列表，后续数据直接追加尽量，列表中的数据都是字典，先把全国的数据添进去

# 各省份的数据都在 data['areaTree'][0]['children']这里，这是个列表，34个省级行政区
provinces = data0['areaTree'][0]['children']
# 遍历这个列表取出每个省的数据和每个地区的数据
for i in provinces:
    # i['total'] 就是每个省的数据，里面的 showRate 和 showHeal 字段是不需要的 等同于这样data['areaTree'][0]['children'][0]['total']
    one_procevice_data = {'name': i['name']} # 将省份的名字先添加进字典
    one_procevice_data.update(i['total']) # 合并具体数据 i['total']是字典型的数据
    provinces_data.append(one_procevice_data) # 向省份列表追加每个省的数据
    
    # 获取省内的各市的数据 省内的数据一次就保存到单独的csv文件中
    districts = i['children']
    districts_data = [one_procevice_data]
    for j in districts:
        one_district_data = {'name': j['name']}
        one_district_data.update(j['total'])
        districts_data.append(one_district_data)
        
    # 将字典构成的列表直接转为DataFrame
    districts_df = pd.DataFrame(districts_data)
    del districts_df['showRate'] # 删除这多余的两列
    del districts_df['showHeal']
    
    # 保存这个省内各市的数据
    # districts_df.rename(columns=field_name_cn, inplace=True) # 把列名改为中文
    df_to_csv(districts_df, filepath_cn+'/各省具体数据', f'{i["name"]}.csv') # 存储各省具体数据
    # districts_df.to_csv(f"{filepath}/{i['name']}.csv", encoding='GBK', retain_index=False) # 保存到文件夹中 

                        
# 将字典构成的列表直接转为DataFrame
provinces_df = pd.DataFrame(provinces_data)                        
del provinces_df['showRate'] # 删除这多余的两列
del provinces_df['showHeal']
                        
# 保存每个省的数据
# provinces_df.rename(columns=field_name_cn, inplace=True) # 把列名改为中文
df_to_csv(provinces_df, filepath_cn, '中国疫情数据.csv')
# provinces_df.to_csv(f"{field_name_cn}/中国.csv", encoding='GBK', retain_index=False) # 保存到文件夹中

# %% [markdown]
# # 国内数据（随时间变化）

# %%
# url1 = 'https://view.inews.qq.com/g2/getOnsInfo?name=disease_other' # 国内数据（随时间变化）
res1 = requests.get(url1, headers=headers)
data1 = json.loads(res1.json()['data']) # 因为data对应的值还是json字符串，还要转成Python字典

# %%
# 该部分可以直接转DataFrame然后存储数据
df_to_csv(pd.DataFrame(data1['chinaDayList']), filepath_cn, '国内历史每日数据.csv')
df_to_csv(pd.DataFrame(data1['chinaDayAddList']), filepath_cn, '国内历史每日新增数据.csv')
df_to_csv(pd.DataFrame(data1['dailyNewAddHistory']), filepath_cn, '历史每日新增确诊数据（湖北、全国、和非湖北）.csv')

# %%
prov_compare = pd.DataFrame(data1['provinceCompare']) # 各省数据比较（现存确诊，新增确诊，死亡，治愈，连续0增天数
prov_compare = pd.DataFrame(prov_compare.values.T, index=prov_compare.columns, columns=prov_compare.index) # 转置
df_to_csv(prov_compare, filepath_cn, '各省今日数据比较.csv', retain_index=True) # 保留索引

# %% [markdown]
# # 外国数据（比率和排名）

# %%
filepath_fg = "./疫情数据/外国数据"

# url2 = 'https://api.inews.qq.com/newsqa/v1/automation/modules/list?modules=FAutoCountryWeekCompRank,FAutoContinentConfirmStatis,FAutoConfirmMillionRankList,FAutoHealDeadRateRankList'
res2 = requests.get(url2, headers=headers2) # 这里用了headers2
data2 = res2.json()['data']

# %%
# 存储数据直接用 二次包装的to_csv方法 这里并没有修改列名为中文
df_to_csv(pd.DataFrame(data2['FAutoConfirmMillionRankList']), filepath_fg, '外国每百万人确诊数.csv')
df_to_csv(pd.DataFrame(data2['FAutoContinentConfirmStatis']), filepath_fg, '外国累计确诊周增幅.csv')
df_to_csv(pd.DataFrame(data2['FAutoCountryWeekCompRank']), filepath_fg, '外国累计确诊七日增幅.csv')
df_to_csv(pd.DataFrame(data2['FAutoHealDeadRateRankList']['deadHead']), filepath_fg, '外国死亡率前10名.csv')
df_to_csv(pd.DataFrame(data2['FAutoHealDeadRateRankList']['deadTail']), filepath_fg, '外国死亡率后10名.csv')
df_to_csv(pd.DataFrame(data2['FAutoHealDeadRateRankList']['healHead']), filepath_fg, '外国治愈前10名.csv')
df_to_csv(pd.DataFrame(data2['FAutoHealDeadRateRankList']['healTail']), filepath_fg, '外国治愈后10名.csv')

# %% [markdown]
# # 外国数据（排名和部分国家具体行政区数据）

# %%
# url3 = 'https://view.inews.qq.com/g2/getOnsInfo?name=disease_foreign' # 外国数据（排名）
res3 = requests.get(url3, headers=headers)
data3 = json.loads(res3.json()['data']) # 因为data对应的值还是json字符串，还要转成Python字典

# %%
# 存储数据
df_to_csv(pd.DataFrame(data3['importStatis']['TopList']), filepath_cn, '国内输入病例前十省.csv')
df_to_csv(pd.DataFrame(data3['countryAddConfirmRankList']), filepath_fg, '外国24小时新增确诊前10名.csv')
df_to_csv(pd.DataFrame(data3['countryConfirmWeekCompareRankList']), filepath_fg, '外国七天变化排名.csv')

# %%
# 存储部分国家的具体行政区数据数据  不过这里面就几个国家，同
for i in data3['foreignList']: # i为国家的数据
    # 先判断这个国家有没有具体类似我国省这样的行政区的数据，即判断有没有 children 这个字段
    if 'children' in i: # 等同于 in i.keys()
        # 当存在时，可直接转换成DataFrame并存储
        df_to_csv(pd.DataFrame(i['children']), filepath_fg+'/部分国家具体行政区数据', f"{i['name']}-具体行政区数据.csv")

# %% [markdown]
# # 全球总体数据（随时间变化）

# %%
# url4 = "https://api.inews.qq.com/newsqa/v1/automation/modules/list?modules=FAutoGlobalStatis,FAutoContinentStatis,FAutoGlobalDailyList,FAutoCountryConfirmAdd"
res4 = requests.get(url4, headers=headers2) # 这里用了headers2
data4 = res4.json()['data']

# %%
for i in data4['FAutoContinentStatis']: # 各大洲历史每七天的数据统计
    i.update(i.pop('statis')) # 把statis弹出再追加进去就可以直接转成DataFrame
# 存储数据
df_to_csv(pd.DataFrame(data4['FAutoContinentStatis']), filepath_fg, '各大洲历史每七天的数据统计.csv')

# %%
global_daily_data = [] # 存储全球每日数据的列表
for i in data4['FAutoGlobalDailyList']:
    day_data = {'date': i['date']}
    day_data.update(i['all']) # 就all字段中的每日数据追加进去
    global_daily_data.append(day_data)
# 存储数据
df_to_csv(pd.DataFrame(global_daily_data), filepath_fg, '全球历史每日数据.csv') # 转换成DataFrame，并存储到本地

# %% [markdown]
# # 外国数据（按国家或大洲查看）

# %%
# url5 = "https://api.inews.qq.com/newsqa/v1/automation/foreign/country/ranklist"
res5 = requests.get(url5, headers=headers2)
data5 = res5.json()['data']

# %%
# 存储
df_to_csv(pd.DataFrame(data5), filepath_fg, '外国疫情数据（按国家或大洲查看）.csv')

# %%
data5
# Out:
# [{'name': '美国',
#   'continent': '北美洲',
#   'date': '07.15',
#   'isUpdated': True,
#   'confirmAdd': 65594,
#   'confirmAddCut': 0,
#   'confirm': 3545077,
#   'suspect': 0,
#   'dead': 139143,
#   'heal': 1600195,
#   'nowConfirm': 1805739,
#   'confirmCompare': 65594,
#   'nowConfirmCompare': 13972,
#   'healCompare': 50726,
#   'deadCompare': 896},
#  {'name': '巴西',
#   'continent': '南美洲',
#   'date': '07.15',
#   'isUpdated': False,
#   'confirmAdd': 41857,
#   'confirmAddCut': 0,
#   'confirm': 1926824,
#   'suspect': 0,
#   'dead': 74133,
#   'heal': 1323425,
#   'nowConfirm': 529266,
#   'confirmCompare': 41857,
#   'nowConfirmCompare': 8383,
#   'healCompare': 32174,
#   'deadCompare': 1300},
#  {'name': '印度',
#   'continent': '亚洲',
#   'date': '07.15',
#   'isUpdated': False,
#   'confirmAdd': 0,
#   'confirmAddCut': 0,
#   'confirm': 906752,
#   'suspect': 0,
#   'dead': 23727,
#   'heal': 571460,
#   'nowConfirm': 311565,
#   'confirmCompare': 0,
#   'nowConfirmCompare': 0,
#   'healCompare': 0,
#   'deadCompare': 0},
#  {'name': '俄罗斯',
#   'continent': '欧洲',
#   'date': '07.15',
#   'isUpdated': False,
#   'confirmAdd': 0,
#   'confirmAddCut': 0,
#   'confirm': 738787,
#   'suspect': 0,
#   'dead': 11597,
#   'heal': 511958,
#   'nowConfirm': 215232,
#   'confirmCompare': 0,
#   'nowConfirmCompare': 0,
#   'healCompare': 0,
#   'deadCompare': 0},
#  {'name': '秘鲁',
#   'continent': '南美洲',
#   'date': '07.15',
#   'isUpdated': False,
#   'confirmAdd': 3744,
#   'confirmAddCut': 0,
#   'confirm': 333867,
#   'suspect': 0,
#   'dead': 12229,
#   'heal': 223261,
#   'nowConfirm': 98377,
#   'confirmCompare': 3744,
#   'nowConfirmCompare': 1316,
#   'healCompare': 2253,
#   'deadCompare': 175},
#  {'name': '智利',
#   'continent': '南美洲',
#   'date': '07.15',
#   'isUpdated': False,
#   'confirmAdd': 1836,
#   'confirmAddCut': 0,
#   'confirm': 319493,
#   'suspect': 0,
#   'dead': 7069,
#   'heal': 289220,
#   'nowConfirm': 23204,
#   'confirmCompare': 1836,
#   'nowConfirmCompare': -873,
#   'healCompare': 2664,
#   'deadCompare': 45},
#  {'name': '墨西哥',
#   'continent': '北美洲',
#   'date': '07.15',
#   'isUpdated': False,
#   'confirmAdd': 7051,
#   'confirmAddCut': 0,
#   'confirm': 311486,
#   'suspect': 0,
#   'dead': 36327,
#   'heal': 245830,
#   'nowConfirm': 29329,
#   'confirmCompare': 7051,
#   'nowConfirmCompare': 486,
#   'healCompare': 5729,
#   'deadCompare': 836},
#  {'name': '西班牙',
#   'continent': '欧洲',
#   'date': '07.15',
#   'isUpdated': True,
#   'confirmAdd': 666,
#   'confirmAddCut': 0,
#   'confirm': 303699,
#   'suspect': 0,
#   'dead': 28409,
#   'heal': 196958,
#   'nowConfirm': 78332,
#   'confirmCompare': 666,
#   'nowConfirmCompare': 663,
#   'healCompare': 0,
#   'deadCompare': 3},
#  {'name': '南非',
#   'continent': '非洲',
#   'date': '07.15',
#   'isUpdated': False,
#   'confirmAdd': 10496,
#   'confirmAddCut': 0,
#   'confirm': 298292,
#   'suspect': 0,
#   'dead': 4346,
#   'heal': 146279,
#   'nowConfirm': 147667,
#   'confirmCompare': 10496,
#   'nowConfirmCompare': 2284,
#   'healCompare': 8038,
#   'deadCompare': 174},
#  {'name': '英国',
#   'continent': '欧洲',
#   'date': '07.15',
#   'isUpdated': False,
#   'confirmAdd': 1240,
#   'confirmAddCut': 0,
#   'confirm': 292931,
#   'suspect': 0,
#   'dead': 45053,
#   'heal': 1385,
#   'nowConfirm': 246493,
#   'confirmCompare': 1240,
#   'nowConfirmCompare': 1101,
#   'healCompare': 1,
#   'deadCompare': 138},
#  {'name': '伊朗',
#   'continent': '亚洲',
#   'date': '07.15',
#   'isUpdated': False,
#   'confirmAdd': 0,
#   'confirmAddCut': 0,
#   'confirm': 262173,
#   'suspect': 0,
#   'dead': 13211,
#   'heal': 225270,
#   'nowConfirm': 23692,
#   'confirmCompare': 0,
#   'nowConfirmCompare': 0,
#   'healCompare': 0,
#   'deadCompare': 0},
#  {'name': '巴基斯坦',
#   'continent': '亚洲',
#   'date': '07.15',
#   'isUpdated': False,
#   'confirmAdd': 0,
#   'confirmAddCut': 0,
#   'confirm': 253604,
#   'suspect': 0,
#   'dead': 5320,
#   'heal': 170656,
#   'nowConfirm': 77628,
#   'confirmCompare': 0,
#   'nowConfirmCompare': 0,
#   'healCompare': 0,
#   'deadCompare': 0},
#  {'name': '意大利',
#   'continent': '欧洲',
#   'date': '07.15',
#   'isUpdated': False,
#   'confirmAdd': 0,
#   'confirmAddCut': 0,
#   'confirm': 243344,
#   'suspect': 0,
#   'dead': 34984,
#   'heal': 195441,
#   'nowConfirm': 12919,
#   'confirmCompare': 0,
#   'nowConfirmCompare': 0,
#   'healCompare': 0,
#   'deadCompare': 0},
#  {'name': '沙特阿拉伯',
#   'continent': '亚洲',
#   'date': '07.15',
#   'isUpdated': False,
#   'confirmAdd': 0,
#   'confirmAddCut': 0,
#   'confirm': 237803,
#   'suspect': 0,
#   'dead': 2283,
#   'heal': 177560,
#   'nowConfirm': 57960,
#   'confirmCompare': 0,
#   'nowConfirmCompare': 0,
#   'healCompare': 0,
#   'deadCompare': 0},
#  {'name': '土耳其',
#   'continent': '亚洲',
#   'date': '07.15',
#   'isUpdated': False,
#   'confirmAdd': 992,
#   'confirmAddCut': 0,
#   'confirm': 214993,
#   'suspect': 0,
#   'dead': 5402,
#   'heal': 196720,
#   'nowConfirm': 12871,
#   'confirmCompare': 992,
#   'nowConfirmCompare': -77,
#   'healCompare': 1049,
#   'deadCompare': 20},
#  {'name': '法国',
#   'continent': '欧洲',
#   'date': '07.15',
#   'isUpdated': False,
#   'confirmAdd': 0,
#   'confirmAddCut': 0,
#   'confirm': 209640,
#   'suspect': 0,
#   'dead': 30032,
#   'heal': 78722,
#   'nowConfirm': 100886,
#   'confirmCompare': 0,
#   'nowConfirmCompare': 0,
#   'healCompare': 0,
#   'deadCompare': 0},
#  {'name': '德国',
#   'continent': '欧洲',
#   'date': '07.15',
#   'isUpdated': False,
#   'confirmAdd': 0,
#   'confirmAddCut': 0,
#   'confirm': 200456,
#   'suspect': 0,
#   'dead': 9078,
#   'heal': 185100,
#   'nowConfirm': 6278,
#   'confirmCompare': 0,
#   'nowConfirmCompare': -1,
#   'healCompare': 0,
#   'deadCompare': 1},
#  {'name': '孟加拉',
#   'continent': '亚洲',
#   'date': '07.15',
#   'isUpdated': False,
#   'confirmAdd': 0,
#   'confirmAddCut': 0,
#   'confirm': 190057,
#   'suspect': 0,
#   'dead': 2424,
#   'heal': 103227,
#   'nowConfirm': 84406,
#   'confirmCompare': 0,
#   'nowConfirmCompare': 0,
#   'healCompare': 0,
#   'deadCompare': 0},
#  {'name': '哥伦比亚',
#   'continent': '南美洲',
#   'date': '07.15',
#   'isUpdated': False,
#   'confirmAdd': 3832,
#   'confirmAddCut': 0,
#   'confirm': 154277,
#   'suspect': 0,
#   'dead': 5787,
#   'heal': 65809,
#   'nowConfirm': 82681,
#   'confirmCompare': 3832,
#   'nowConfirmCompare': 1321,
#   'healCompare': 2358,
#   'deadCompare': 153},
#  {'name': '加拿大',
#   'continent': '北美洲',
#   'date': '07.15',
#   'isUpdated': False,
#   'confirmAdd': 292,
#   'confirmAddCut': 0,
#   'confirm': 110350,
#   'suspect': 0,
#   'dead': 8845,
#   'heal': 73713,
#   'nowConfirm': 27792,
#   'confirmCompare': 292,
#   'nowConfirmCompare': -10,
#   'healCompare': 293,
#   'deadCompare': 9},
#  {'name': '阿根廷',
#   'continent': '南美洲',
#   'date': '07.15',
#   'isUpdated': False,
#   'confirmAdd': 3645,
#   'confirmAddCut': 0,
#   'confirm': 106910,
#   'suspect': 0,
#   'dead': 1968,
#   'heal': 45467,
#   'nowConfirm': 59475,
#   'confirmCompare': 3645,
#   'nowConfirmCompare': 3603,
#   'healCompare': 0,
#   'deadCompare': 42},
#  {'name': '卡塔尔',
#   'continent': '亚洲',
#   'date': '07.15',
#   'isUpdated': False,
#   'confirmAdd': 0,
#   'confirmAddCut': 0,
#   'confirm': 104533,
#   'suspect': 0,
#   'dead': 150,
#   'heal': 101160,
#   'nowConfirm': 3223,
#   'confirmCompare': 0,
#   'nowConfirmCompare': 0,
#   'healCompare': 0,
#   'deadCompare': 0},
#  {'name': '埃及',
#   'continent': '非洲',
#   'date': '07.15',
#   'isUpdated': False,
#   'confirmAdd': 929,
#   'confirmAddCut': 0,
#   'confirm': 83930,
#   'suspect': 0,
#   'dead': 4008,
#   'heal': 25544,
#   'nowConfirm': 54378,
#   'confirmCompare': 929,
#   'nowConfirmCompare': 287,
#   'healCompare': 569,
#   'deadCompare': 73},
#  {'name': '伊拉克',
#   'continent': '亚洲',
#   'date': '07.15',
#   'isUpdated': False,
#   'confirmAdd': 0,
#   'confirmAddCut': 0,
#   'confirm': 81757,
#   'suspect': 0,
#   'dead': 3345,
#   'heal': 50782,
#   'nowConfirm': 27630,
#   'confirmCompare': 0,
#   'nowConfirmCompare': 0,
#   'healCompare': 0,
#   'deadCompare': 0},
#  {'name': '印度尼西亚',
#   'continent': '亚洲',
#   'date': '07.15',
#   'isUpdated': False,
#   'confirmAdd': 0,
#   'confirmAddCut': 0,
#   'confirm': 78572,
#   'suspect': 0,
#   'dead': 3710,
#   'heal': 37636,
#   'nowConfirm': 37226,
#   'confirmCompare': 0,
#   'nowConfirmCompare': 0,
#   'healCompare': 0,
#   'deadCompare': 0},
#  {'name': '瑞典',
#   'continent': '欧洲',
#   'date': '07.15',
#   'isUpdated': False,
#   'confirmAdd': 0,
#   'confirmAddCut': 0,
#   'confirm': 76001,
#   'suspect': 0,
#   'dead': 5545,
#   'heal': 4971,
#   'nowConfirm': 65485,
#   'confirmCompare': 0,
#   'nowConfirmCompare': 0,
#   'healCompare': 0,
#   'deadCompare': 0},
#  {'name': '厄瓜多尔',
#   'continent': '南美洲',
#   'date': '07.15',
#   'isUpdated': False,
#   'confirmAdd': 1111,
#   'confirmAddCut': 0,
#   'confirm': 69570,
#   'suspect': 0,
#   'dead': 5130,
#   'heal': 30484,
#   'nowConfirm': 33956,
#   'confirmCompare': 1111,
#   'nowConfirmCompare': 929,
#   'healCompare': 115,
#   'deadCompare': 67},
#  {'name': '白俄罗斯',
#   'continent': '欧洲',
#   'date': '07.15',
#   'isUpdated': False,
#   'confirmAdd': 0,
#   'confirmAddCut': 0,
#   'confirm': 65269,
#   'suspect': 0,
#   'dead': 474,
#   'heal': 55799,
#   'nowConfirm': 8996,
#   'confirmCompare': 0,
#   'nowConfirmCompare': 0,
#   'healCompare': 0,
#   'deadCompare': 0},
#  {'name': '比利时',
#   'continent': '欧洲',
#   'date': '07.15',
#   'isUpdated': False,
#   'confirmAdd': 0,
#   'confirmAddCut': 0,
#   'confirm': 62781,
#   'suspect': 0,
#   'dead': 9787,
#   'heal': 17223,
#   'nowConfirm': 35771,
#   'confirmCompare': 0,
#   'nowConfirmCompare': 0,
#   'healCompare': 0,
#   'deadCompare': 0},
#  {'name': '哈萨克斯坦',
#   'continent': '亚洲',
#   'date': '07.15',
#   'isUpdated': False,
#   'confirmAdd': 0,
#   'confirmAddCut': 0,
#   'confirm': 61755,
#   'suspect': 0,
#   'dead': 375,
#   'heal': 35911,
#   'nowConfirm': 25469,
#   'confirmCompare': 0,
#   'nowConfirmCompare': 0,
#   'healCompare': 0,
#   'deadCompare': 0},
#  {'name': '阿曼',
#   'continent': '亚洲',
#   'date': '07.15',
#   'isUpdated': False,
#   'confirmAdd': 0,
#   'confirmAddCut': 0,
#   'confirm': 59568,
#   'suspect': 0,
#   'dead': 273,
#   'heal': 37987,
#   'nowConfirm': 21308,
#   'confirmCompare': 0,
#   'nowConfirmCompare': 0,
#   'healCompare': 0,
#   'deadCompare': 0},
#  {'name': '菲律宾',
#   'continent': '亚洲',
#   'date': '07.15',
#   'isUpdated': False,
#   'confirmAdd': 0,
#   'confirmAddCut': 0,
#   'confirm': 57545,
#   'suspect': 0,
#   'dead': 1603,
#   'heal': 20459,
#   'nowConfirm': 35483,
#   'confirmCompare': 0,
#   'nowConfirmCompare': 0,
#   'healCompare': 0,
#   'deadCompare': 0},
#  {'name': '科威特',
#   'continent': '亚洲',
#   'date': '07.15',
#   'isUpdated': False,
#   'confirmAdd': 0,
#   'confirmAddCut': 0,
#   'confirm': 56174,
#   'suspect': 0,
#   'dead': 396,
#   'heal': 46161,
#   'nowConfirm': 9617,
#   'confirmCompare': 0,
#   'nowConfirmCompare': 0,
#   'healCompare': 0,
#   'deadCompare': 0},
#  {'name': '乌克兰',
#   'continent': '欧洲',
#   'date': '07.15',
#   'isUpdated': False,
#   'confirmAdd': 0,
#   'confirmAddCut': 0,
#   'confirm': 55931,
#   'suspect': 0,
#   'dead': 1429,
#   'heal': 28021,
#   'nowConfirm': 26481,
#   'confirmCompare': 0,
#   'nowConfirmCompare': 0,
#   'healCompare': 0,
#   'deadCompare': 0},
#  {'name': '阿联酋',
#   'continent': '亚洲',
#   'date': '07.15',
#   'isUpdated': False,
#   'confirmAdd': 375,
#   'confirmAddCut': 0,
#   'confirm': 55573,
#   'suspect': 0,
#   'dead': 335,
#   'heal': 46025,
#   'nowConfirm': 9213,
#   'confirmCompare': 375,
#   'nowConfirmCompare': -138,
#   'healCompare': 512,
#   'deadCompare': 1},
#  {'name': '荷兰',
#   'continent': '欧洲',
#   'date': '07.15',
#   'isUpdated': False,
#   'confirmAdd': 1,
#   'confirmAddCut': 0,
#   'confirm': 51362,
#   'suspect': 0,
#   'dead': 6154,
#   'heal': 193,
#   'nowConfirm': 45015,
#   'confirmCompare': 1,
#   'nowConfirmCompare': 1,
#   'healCompare': 0,
#   'deadCompare': 0},
#  {'name': '玻利维亚',
#   'continent': '南美洲',
#   'date': '07.15',
#   'isUpdated': False,
#   'confirmAdd': 1617,
#   'confirmAddCut': 0,
#   'confirm': 50867,
#   'suspect': 0,
#   'dead': 1898,
#   'heal': 15819,
#   'nowConfirm': 33150,
#   'confirmCompare': 1617,
#   'nowConfirmCompare': 1060,
#   'healCompare': 525,
#   'deadCompare': 32},
#  {'name': '巴拿马',
#   'continent': '北美洲',
#   'date': '07.15',
#   'isUpdated': False,
#   'confirmAdd': 923,
#   'confirmAddCut': 0,
#   'confirm': 48096,
#   'suspect': 0,
#   'dead': 960,
#   'heal': 24667,
#   'nowConfirm': 22469,
#   'confirmCompare': 923,
#   'nowConfirmCompare': 147,
#   'healCompare': 748,
#   'deadCompare': 28},
#  {'name': '葡萄牙',
#   'continent': '欧洲',
#   'date': '07.15',
#   'isUpdated': False,
#   'confirmAdd': 0,
#   'confirmAddCut': 0,
#   'confirm': 47051,
#   'suspect': 0,
#   'dead': 1668,
#   'heal': 31550,
#   'nowConfirm': 13833,
#   'confirmCompare': 0,
#   'nowConfirmCompare': 0,
#   'healCompare': 0,
#   'deadCompare': 0},
#  {'name': '新加坡',
#   'continent': '亚洲',
#   'date': '07.15',
#   'isUpdated': False,
#   'confirmAdd': 0,
#   'confirmAddCut': 0,
#   'confirm': 46630,
#   'suspect': 0,
#   'dead': 27,
#   'heal': 42737,
#   'nowConfirm': 3866,
#   'confirmCompare': 0,
#   'nowConfirmCompare': 0,
#   'healCompare': 0,
#   'deadCompare': 0},
#  {'name': '多米尼加',
#   'continent': '北美洲',
#   'date': '07.15',
#   'isUpdated': False,
#   'confirmAdd': 0,
#   'confirmAddCut': 0,
#   'confirm': 46305,
#   'suspect': 0,
#   'dead': 910,
#   'heal': 23134,
#   'nowConfirm': 22261,
#   'confirmCompare': 0,
#   'nowConfirmCompare': 0,
#   'healCompare': 0,
#   'deadCompare': 0},
#  {'name': '以色列',
#   'continent': '亚洲',
#   'date': '07.15',
#   'isUpdated': False,
#   'confirmAdd': 1125,
#   'confirmAddCut': 0,
#   'confirm': 42360,
#   'suspect': 0,
#   'dead': 371,
#   'heal': 19665,
#   'nowConfirm': 22324,
#   'confirmCompare': 1125,
#   'nowConfirmCompare': 931,
#   'healCompare': 191,
#   'deadCompare': 3},
#  {'name': '波兰',
#   'continent': '欧洲',
#   'date': '07.15',
#   'isUpdated': False,
#   'confirmAdd': 0,
#   'confirmAddCut': 0,
#   'confirm': 38457,
#   'suspect': 0,
#   'dead': 1588,
#   'heal': 27756,
#   'nowConfirm': 9113,
#   'confirmCompare': 0,
#   'nowConfirmCompare': 0,
#   'healCompare': 0,
#   'deadCompare': 0},
#  {'name': '阿富汗',
#   'continent': '亚洲',
#   'date': '07.15',
#   'isUpdated': False,
#   'confirmAdd': 0,
#   'confirmAddCut': 0,
#   'confirm': 34740,
#   'suspect': 0,
#   'dead': 1048,
#   'heal': 21454,
#   'nowConfirm': 12238,
#   'confirmCompare': 0,
#   'nowConfirmCompare': 0,
#   'healCompare': 0,
#   'deadCompare': 0},
#  {'name': '巴林',
#   'continent': '亚洲',
#   'date': '07.15',
#   'isUpdated': False,
#   'confirmAdd': 602,
#   'confirmAddCut': 0,
#   'confirm': 34078,
#   'suspect': 0,
#   'dead': 111,
#   'heal': 29753,
#   'nowConfirm': 4214,
#   'confirmCompare': 602,
#   'nowConfirmCompare': -54,
#   'healCompare': 654,
#   'deadCompare': 2},
#  {'name': '尼日利亚',
#   'continent': '非洲',
#   'date': '07.15',
#   'isUpdated': False,
#   'confirmAdd': 463,
#   'confirmAddCut': 0,
#   'confirm': 33616,
#   'suspect': 0,
#   'dead': 754,
#   'heal': 13792,
#   'nowConfirm': 19070,
#   'confirmCompare': 463,
#   'nowConfirmCompare': 332,
#   'healCompare': 121,
#   'deadCompare': 10},
#  {'name': '罗马尼亚',
#   'continent': '欧洲',
#   'date': '07.15',
#   'isUpdated': False,
#   'confirmAdd': 0,
#   'confirmAddCut': 0,
#   'confirm': 33585,
#   'suspect': 0,
#   'dead': 1931,
#   'heal': 21803,
#   'nowConfirm': 9851,
#   'confirmCompare': 0,
#   'nowConfirmCompare': 0,
#   'healCompare': 0,
#   'deadCompare': 0},
#  {'name': '瑞士',
#   'continent': '欧洲',
#   'date': '07.15',
#   'isUpdated': False,
#   'confirmAdd': 0,
#   'confirmAddCut': 0,
#   'confirm': 33016,
#   'suspect': 0,
#   'dead': 1968,
#   'heal': 29800,
#   'nowConfirm': 1248,
#   'confirmCompare': 0,
#   'nowConfirmCompare': -200,
#   'healCompare': 200,
#   'deadCompare': 0},
#  {'name': '亚美尼亚',
#   'continent': '亚洲',
#   'date': '07.15',
#   'isUpdated': False,
#   'confirmAdd': 0,
#   'confirmAddCut': 0,
#   'confirm': 32490,
#   'suspect': 0,
#   'dead': 581,
#   'heal': 20729,
#   'nowConfirm': 11180,
#   'confirmCompare': 0,
#   'nowConfirmCompare': 0,
#   'healCompare': 0,
#   'deadCompare': 0},
#  {'name': '危地马拉',
#   'continent': '北美洲',
#   'date': '07.15',
#   'isUpdated': False,
#   'confirmAdd': 1130,
#   'confirmAddCut': 0,
#   'confirm': 30872,
#   'suspect': 0,
#   'dead': 1302,
#   'heal': 4453,
#   'nowConfirm': 25117,
#   'confirmCompare': 1130,
#   'nowConfirmCompare': 940,
#   'healCompare': 132,
#   'deadCompare': 58},
#  {'name': '洪都拉斯',
#   'continent': '北美洲',
#   'date': '07.15',
#   'isUpdated': False,
#   'confirmAdd': 0,
#   'confirmAddCut': 0,
#   'confirm': 28579,
#   'suspect': 0,
#   'dead': 789,
#   'heal': 3123,
#   'nowConfirm': 24667,
#   'confirmCompare': 0,
#   'nowConfirmCompare': 0,
#   'healCompare': 0,
#   'deadCompare': 0},
#  {'name': '爱尔兰',
#   'continent': '欧洲',
#   'date': '07.15',
#   'isUpdated': False,
#   'confirmAdd': 32,
#   'confirmAddCut': 0,
#   'confirm': 25670,
#   'suspect': 0,
#   'dead': 1746,
#   'heal': 23364,
#   'nowConfirm': 560,
#   'confirmCompare': 32,
#   'nowConfirmCompare': 32,
#   'healCompare': 0,
#   'deadCompare': 0},
#  {'name': '阿塞拜疆',
#   'continent': '亚洲',
#   'date': '07.15',
#   'isUpdated': False,
#   'confirmAdd': 543,
#   'confirmAddCut': 0,
#   'confirm': 25113,
#   'suspect': 0,
#   'dead': 319,
#   'heal': 16150,
#   'nowConfirm': 8644,
#   'confirmCompare': 543,
#   'nowConfirmCompare': 27,
#   'healCompare': 510,
#   'deadCompare': 6},
#  {'name': '加纳',
#   'continent': '非洲',
#   'date': '07.15',
#   'isUpdated': False,
#   'confirmAdd': 0,
#   'confirmAddCut': 0,
#   'confirm': 24988,
#   'suspect': 0,
#   'dead': 139,
#   'heal': 21067,
#   'nowConfirm': 3782,
#   'confirmCompare': 0,
#   'nowConfirmCompare': 0,
#   'healCompare': 0,
#   'deadCompare': 0},
#  {'name': '日本本土',
#   'continent': '亚洲',
#   'date': '07.15',
#   'isUpdated': False,
#   'confirmAdd': 0,
#   'confirmAddCut': 0,
#   'confirm': 22431,
#   'suspect': 0,
#   'dead': 984,
#   'heal': 18126,
#   'nowConfirm': 3321,
#   'confirmCompare': 0,
#   'nowConfirmCompare': 0,
#   'healCompare': 0,
#   'deadCompare': 0},
#  {'name': '阿尔及利亚',
#   'continent': '非洲',
#   'date': '07.15',
#   'isUpdated': False,
#   'confirmAdd': 527,
#   'confirmAddCut': 0,
#   'confirm': 20216,
#   'suspect': 0,
#   'dead': 1028,
#   'heal': 14295,
#   'nowConfirm': 4893,
#   'confirmCompare': 527,
#   'nowConfirmCompare': 241,
#   'healCompare': 276,
#   'deadCompare': 10},
#  {'name': '摩尔多瓦',
#   'continent': '欧洲',
#   'date': '07.15',
#   'isUpdated': False,
#   'confirmAdd': 269,
#   'confirmAddCut': 0,
#   'confirm': 19708,
#   'suspect': 0,
#   'dead': 655,
#   'heal': 13033,
#   'nowConfirm': 6020,
#   'confirmCompare': 269,
#   'nowConfirmCompare': 266,
#   'healCompare': 0,
#   'deadCompare': 3},
#  {'name': '奥地利',
#   'continent': '欧洲',
#   'date': '07.15',
#   'isUpdated': False,
#   'confirmAdd': 0,
#   'confirmAddCut': 0,
#   'confirm': 19021,
#   'suspect': 0,
#   'dead': 709,
#   'heal': 17073,
#   'nowConfirm': 1239,
#   'confirmCompare': 0,
#   'nowConfirmCompare': 0,
#   'healCompare': 0,
#   'deadCompare': 0},
#  {'name': '塞尔维亚',
#   'continent': '欧洲',
#   'date': '07.15',
#   'isUpdated': False,
#   'confirmAdd': 0,
#   'confirmAddCut': 0,
#   'confirm': 18983,
#   'suspect': 0,
#   'dead': 418,
#   'heal': 13991,
#   'nowConfirm': 4574,
#   'confirmCompare': 0,
#   'nowConfirmCompare': 0,
#   'healCompare': 0,
#   'deadCompare': 0},
#  {'name': '尼泊尔',
#   'continent': '亚洲',
#   'date': '07.15',
#   'isUpdated': False,
#   'confirmAdd': 0,
#   'confirmAddCut': 0,
#   'confirm': 17061,
#   'suspect': 0,
#   'dead': 38,
#   'heal': 10328,
#   'nowConfirm': 6695,
#   'confirmCompare': 0,
#   'nowConfirmCompare': 0,
#   'healCompare': 0,
#   'deadCompare': 0},
#  {'name': '摩洛哥',
#   'continent': '非洲',
#   'date': '07.15',
#   'isUpdated': False,
#   'confirmAdd': 50,
#   'confirmAddCut': 0,
#   'confirm': 16097,
#   'suspect': 0,
#   'dead': 257,
#   'heal': 13442,
#   'nowConfirm': 2398,
#   'confirmCompare': 50,
#   'nowConfirmCompare': 10,
#   'healCompare': 39,
#   'deadCompare': 1},
#  {'name': '喀麦隆',
#   'continent': '非洲',
#   'date': '07.15',
#   'isUpdated': False,
#   'confirmAdd': 0,
#   'confirmAddCut': 0,
#   'confirm': 15173,
#   'suspect': 0,
#   'dead': 359,
#   'heal': 11928,
#   'nowConfirm': 2886,
#   'confirmCompare': 0,
#   'nowConfirmCompare': 0,
#   'healCompare': 0,
#   'deadCompare': 0},
#  {'name': '乌兹别克斯坦',
#   'continent': '亚洲',
#   'date': '07.15',
#   'isUpdated': False,
#   'confirmAdd': 92,
#   'confirmAddCut': 0,
#   'confirm': 14085,
#   'suspect': 0,
#   'dead': 67,
#   'heal': 8327,
#   'nowConfirm': 5691,
#   'confirmCompare': 92,
#   'nowConfirmCompare': -163,
#   'healCompare': 253,
#   'deadCompare': 2},
#  {'name': '韩国',
#   'continent': '亚洲',
#   'date': '07.15',
#   'isUpdated': False,
#   'confirmAdd': 39,
#   'confirmAddCut': 0,
#   'confirm': 13551,
#   'suspect': 0,
#   'dead': 289,
#   'heal': 12348,
#   'nowConfirm': 914,
#   'confirmCompare': 39,
#   'nowConfirmCompare': -27,
#   'healCompare': 66,
#   'deadCompare': 0},
#  {'name': '捷克',
#   'continent': '欧洲',
#   'date': '07.15',
#   'isUpdated': False,
#   'confirmAdd': 103,
#   'confirmAddCut': 0,
#   'confirm': 13341,
#   'suspect': 0,
#   'dead': 355,
#   'heal': 8441,
#   'nowConfirm': 4545,
#   'confirmCompare': 103,
#   'nowConfirmCompare': 33,
#   'healCompare': 68,
#   'deadCompare': 2},
#  {'name': '丹麦',
#   'continent': '欧洲',
#   'date': '07.15',
#   'isUpdated': False,
#   'confirmAdd': 0,
#   'confirmAddCut': 0,
#   'confirm': 13262,
#   'suspect': 0,
#   'dead': 610,
#   'heal': 12361,
#   'nowConfirm': 291,
#   'confirmCompare': 0,
#   'nowConfirmCompare': 0,
#   'healCompare': 0,
#   'deadCompare': 0},
#  {'name': '科特迪瓦',
#   'continent': '非洲',
#   'date': '07.15',
#   'isUpdated': False,
#   'confirmAdd': 165,
#   'confirmAddCut': 0,
#   'confirm': 13037,
#   'suspect': 0,
#   'dead': 87,
#   'heal': 6908,
#   'nowConfirm': 6042,
#   'confirmCompare': 165,
#   'nowConfirmCompare': 64,
#   'healCompare': 98,
#   'deadCompare': 3},
#  {'name': '吉尔吉斯斯坦',
#   'continent': '亚洲',
#   'date': '07.15',
#   'isUpdated': False,
#   'confirmAdd': 0,
#   'confirmAddCut': 0,
#   'confirm': 11444,
#   'suspect': 0,
#   'dead': 149,
#   'heal': 3538,
#   'nowConfirm': 7757,
#   'confirmCompare': 0,
#   'nowConfirmCompare': 0,
#   'healCompare': 0,
#   'deadCompare': 0},
#  {'name': '肯尼亚',
#   'continent': '非洲',
#   'date': '07.15',
#   'isUpdated': False,
#   'confirmAdd': 0,
#   'confirmAddCut': 0,
#   'confirm': 10791,
#   'suspect': 0,
#   'dead': 202,
#   'heal': 3017,
#   'nowConfirm': 7572,
#   'confirmCompare': 0,
#   'nowConfirmCompare': 0,
#   'healCompare': 0,
#   'deadCompare': 0},
#  {'name': '澳大利亚',
#   'continent': '大洋洲',
#   'date': '07.15',
#   'isUpdated': False,
#   'confirmAdd': 236,
#   'confirmAddCut': 0,
#   'confirm': 10487,
#   'suspect': 0,
#   'dead': 111,
#   'heal': 7928,
#   'nowConfirm': 2448,
#   'confirmCompare': 236,
#   'nowConfirmCompare': 142,
#   'healCompare': 93,
#   'deadCompare': 1},
#  {'name': '苏丹',
#   'continent': '非洲',
#   'date': '07.15',
#   'isUpdated': False,
#   'confirmAdd': 101,
#   'confirmAddCut': 0,
#   'confirm': 10417,
#   'suspect': 0,
#   'dead': 659,
#   'heal': 5579,
#   'nowConfirm': 4179,
#   'confirmCompare': 101,
#   'nowConfirmCompare': -77,
#   'healCompare': 176,
#   'deadCompare': 2},
#  {'name': '萨尔瓦多',
#   'continent': '北美洲',
#   'date': '07.15',
#   'isUpdated': False,
#   'confirmAdd': 0,
#   'confirmAddCut': 0,
#   'confirm': 10303,
#   'suspect': 0,
#   'dead': 278,
#   'heal': 5919,
#   'nowConfirm': 4106,
#   'confirmCompare': 0,
#   'nowConfirmCompare': 0,
#   'healCompare': 0,
#   'deadCompare': 0},
#  {'name': '委内瑞拉',
#   'continent': '南美洲',
#   'date': '07.15',
#   'isUpdated': False,
#   'confirmAdd': 303,
#   'confirmAddCut': 0,
#   'confirm': 10010,
#   'suspect': 0,
#   'dead': 96,
#   'heal': 2671,
#   'nowConfirm': 7243,
#   'confirmCompare': 303,
#   'nowConfirmCompare': 300,
#   'healCompare': 0,
#   'deadCompare': 3},
#  {'name': '挪威',
#   'continent': '欧洲',
#   'date': '07.15',
#   'isUpdated': False,
#   'confirmAdd': 13,
#   'confirmAddCut': 0,
#   'confirm': 9001,
#   'suspect': 0,
#   'dead': 253,
#   'heal': 8138,
#   'nowConfirm': 610,
#   'confirmCompare': 13,
#   'nowConfirmCompare': 13,
#   'healCompare': 0,
#   'deadCompare': 0},
#  {'name': '马来西亚',
#   'continent': '亚洲',
#   'date': '07.15',
#   'isUpdated': False,
#   'confirmAdd': 0,
#   'confirmAddCut': 0,
#   'confirm': 8729,
#   'suspect': 0,
#   'dead': 122,
#   'heal': 8524,
#   'nowConfirm': 83,
#   'confirmCompare': 0,
#   'nowConfirmCompare': 0,
#   'healCompare': 0,
#   'deadCompare': 0},
#  {'name': '哥斯达黎加',
#   'continent': '北美洲',
#   'date': '07.15',
#   'isUpdated': False,
#   'confirmAdd': 446,
#   'confirmAddCut': 0,
#   'confirm': 8482,
#   'suspect': 0,
#   'dead': 37,
#   'heal': 2441,
#   'nowConfirm': 6004,
#   'confirmCompare': 446,
#   'nowConfirmCompare': 306,
#   'healCompare': 137,
#   'deadCompare': 3},
#  {'name': '北马其顿',
#   'continent': '欧洲',
#   'date': '07.15',
#   'isUpdated': False,
#   'confirmAdd': 0,
#   'confirmAddCut': 0,
#   'confirm': 8332,
#   'suspect': 0,
#   'dead': 389,
#   'heal': 4468,
#   'nowConfirm': 3475,
#   'confirmCompare': 0,
#   'nowConfirmCompare': 0,
#   'healCompare': 0,
#   'deadCompare': 0},
#  {'name': '塞内加尔',
#   'continent': '非洲',
#   'date': '07.15',
#   'isUpdated': False,
#   'confirmAdd': 0,
#   'confirmAddCut': 0,
#   'confirm': 8243,
#   'suspect': 0,
#   'dead': 150,
#   'heal': 5580,
#   'nowConfirm': 2513,
#   'confirmCompare': 0,
#   'nowConfirmCompare': 0,
#   'healCompare': 0,
#   'deadCompare': 0},
#  {'name': '刚果（金）',
#   'continent': '非洲',
#   'date': '07.15',
#   'isUpdated': False,
#   'confirmAdd': 0,
#   'confirmAddCut': 0,
#   'confirm': 8135,
#   'suspect': 0,
#   'dead': 190,
#   'heal': 3948,
#   'nowConfirm': 3997,
#   'confirmCompare': 0,
#   'nowConfirmCompare': 0,
#   'healCompare': 0,
#   'deadCompare': 0},
#  {'name': '埃塞俄比亚',
#   'continent': '非洲',
#   'date': '07.15',
#   'isUpdated': False,
#   'confirmAdd': 203,
#   'confirmAddCut': 0,
#   'confirm': 7969,
#   'suspect': 0,
#   'dead': 139,
#   'heal': 2430,
#   'nowConfirm': 5400,
#   'confirmCompare': 203,
#   'nowConfirmCompare': 192,
#   'healCompare': 0,
#   'deadCompare': 11},
#  {'name': '保加利亚',
#   'continent': '欧洲',
#   'date': '07.15',
#   'isUpdated': False,
#   'confirmAdd': 234,
#   'confirmAddCut': 0,
#   'confirm': 7645,
#   'suspect': 0,
#   'dead': 283,
#   'heal': 3663,
#   'nowConfirm': 3699,
#   'confirmCompare': 234,
#   'nowConfirmCompare': 81,
#   'healCompare': 146,
#   'deadCompare': 7},
#  {'name': '芬兰',
#   'continent': '欧洲',
#   'date': '07.15',
#   'isUpdated': False,
#   'confirmAdd': 0,
#   'confirmAddCut': 0,
#   'confirm': 7301,
#   'suspect': 0,
#   'dead': 329,
#   'heal': 6800,
#   'nowConfirm': 172,
#   'confirmCompare': 0,
#   'nowConfirmCompare': 0,
#   'healCompare': 0,
#   'deadCompare': 0},
#  {'name': '波黑',
#   'continent': '欧洲',
#   'date': '07.15',
#   'isUpdated': False,
#   'confirmAdd': 0,
#   'confirmAddCut': 0,
#   'confirm': 6981,
#   'suspect': 0,
#   'dead': 226,
#   'heal': 3179,
#   'nowConfirm': 3576,
#   'confirmCompare': 0,
#   'nowConfirmCompare': 0,
#   'healCompare': 0,
#   'deadCompare': 0},
#  {'name': '巴勒斯坦',
#   'continent': '亚洲',
#   'date': '07.15',
#   'isUpdated': False,
#   'confirmAdd': 0,
#   'confirmAddCut': 0,
#   'confirm': 6764,
#   'suspect': 0,
#   'dead': 44,
#   'heal': 1084,
#   'nowConfirm': 5636,
#   'confirmCompare': 0,
#   'nowConfirmCompare': 0,
#   'healCompare': 0,
#   'deadCompare': 0},
#  {'name': '海地',
#   'continent': '北美洲',
#   'date': '07.15',
#   'isUpdated': False,
#   'confirmAdd': 0,
#   'confirmAddCut': 0,
#   'confirm': 6727,
#   'suspect': 0,
#   'dead': 141,
#   'heal': 3022,
#   'nowConfirm': 3564,
#   'confirmCompare': 0,
#   'nowConfirmCompare': 0,
#   'healCompare': 0,
#   'deadCompare': 0},
#  {'name': '塔吉克斯坦',
#   'continent': '亚洲',
#   'date': '07.15',
#   'isUpdated': False,
#   'confirmAdd': 47,
#   'confirmAddCut': 0,
#   'confirm': 6643,
#   'suspect': 0,
#   'dead': 56,
#   'heal': 5332,
#   'nowConfirm': 1255,
#   'confirmCompare': 47,
#   'nowConfirmCompare': -8,
#   'healCompare': 54,
#   'deadCompare': 1},
#  {'name': '几内亚',
#   'continent': '非洲',
#   'date': '07.15',
#   'isUpdated': False,
#   'confirmAdd': 59,
#   'confirmAddCut': 0,
#   'confirm': 6200,
#   'suspect': 0,
#   'dead': 38,
#   'heal': 4951,
#   'nowConfirm': 1211,
#   'confirmCompare': 59,
#   'nowConfirmCompare': -31,
#   'healCompare': 89,
#   'deadCompare': 1},
#  {'name': '加蓬',
#   'continent': '非洲',
#   'date': '07.15',
#   'isUpdated': False,
#   'confirmAdd': 0,
#   'confirmAddCut': 0,
#   'confirm': 6026,
#   'suspect': 0,
#   'dead': 46,
#   'heal': 3475,
#   'nowConfirm': 2505,
#   'confirmCompare': 0,
#   'nowConfirmCompare': 0,
#   'healCompare': 0,
#   'deadCompare': 0},
#  {'name': '毛里塔尼亚',
#   'continent': '非洲',
#   'date': '07.15',
#   'isUpdated': False,
#   'confirmAdd': 72,
#   'confirmAddCut': 0,
#   'confirm': 5518,
#   'suspect': 0,
#   'dead': 147,
#   'heal': 2664,
#   'nowConfirm': 2707,
#   'confirmCompare': 72,
#   'nowConfirmCompare': -91,
#   'healCompare': 163,
#   'deadCompare': 0},
#  {'name': '马达加斯加',
#   'continent': '非洲',
#   'date': '07.15',
#   'isUpdated': False,
#   'confirmAdd': 0,
#   'confirmAddCut': 0,
#   'confirm': 5343,
#   'suspect': 0,
#   'dead': 39,
#   'heal': 2646,
#   'nowConfirm': 2658,
#   'confirmCompare': 0,
#   'nowConfirmCompare': 0,
#   'healCompare': 0,
#   'deadCompare': 0},
#  {'name': '卢森堡',
#   'continent': '欧洲',
#   'date': '07.15',
#   'isUpdated': False,
#   'confirmAdd': 100,
#   'confirmAddCut': 0,
#   'confirm': 5056,
#   'suspect': 0,
#   'dead': 111,
#   'heal': 4195,
#   'nowConfirm': 750,
#   'confirmCompare': 100,
#   'nowConfirmCompare': 88,
#   'healCompare': 12,
#   'deadCompare': 0},
#  {'name': '吉布提',
#   'continent': '非洲',
#   'date': '07.15',
#   'isUpdated': False,
#   'confirmAdd': 0,
#   'confirmAddCut': 0,
#   'confirm': 4979,
#   'suspect': 0,
#   'dead': 56,
#   'heal': 4743,
#   'nowConfirm': 180,
#   'confirmCompare': 0,
#   'nowConfirmCompare': 0,
#   'healCompare': 0,
#   'deadCompare': 0},
#  {'name': '中非共和国',
#   'continent': '非洲',
#   'date': '07.15',
#   'isUpdated': False,
#   'confirmAdd': 35,
#   'confirmAddCut': 0,
#   'confirm': 4356,
#   'suspect': 0,
#   'dead': 53,
#   'heal': 1229,
#   'nowConfirm': 3074,
#   'confirmCompare': 35,
#   'nowConfirmCompare': 14,
#   'healCompare': 21,
#   'deadCompare': 0},
#  {'name': '匈牙利',
#   'continent': '欧洲',
#   'date': '07.15',
#   'isUpdated': False,
#   'confirmAdd': 0,
#   'confirmAddCut': 0,
#   'confirm': 4258,
#   'suspect': 0,
#   'dead': 595,
#   'heal': 3106,
#   'nowConfirm': 557,
#   'confirmCompare': 0,
#   'nowConfirmCompare': 0,
#   'healCompare': 0,
#   'deadCompare': 0},
#  {'name': '希腊',
#   'continent': '欧洲',
#   'date': '07.15',
#   'isUpdated': False,
#   'confirmAdd': 57,
#   'confirmAddCut': 0,
#   'confirm': 3883,
#   'suspect': 0,
#   'dead': 193,
#   'heal': 1374,
#   'nowConfirm': 2316,
#   'confirmCompare': 57,
#   'nowConfirmCompare': 57,
#   'healCompare': 0,
#   'deadCompare': 0},
#  {'name': '克罗地亚',
#   'continent': '欧洲',
#   'date': '07.15',
#   'isUpdated': False,
#   'confirmAdd': 0,
#   'confirmAddCut': 0,
#   'confirm': 3827,
#   'suspect': 0,
#   'dead': 120,
#   'heal': 2558,
#   'nowConfirm': 1149,
#   'confirmCompare': 0,
#   'nowConfirmCompare': 0,
#   'healCompare': 0,
#   'deadCompare': 0},
#  {'name': '阿尔巴尼亚',
#   'continent': '欧洲',
#   'date': '07.15',
#   'isUpdated': False,
#   'confirmAdd': 0,
#   'confirmAddCut': 0,
#   'confirm': 3667,
#   'suspect': 0,
#   'dead': 97,
#   'heal': 2062,
#   'nowConfirm': 1508,
#   'confirmCompare': 0,
#   'nowConfirmCompare': 0,
#   'healCompare': 0,
#   'deadCompare': 0},
#  {'name': '泰国',
#   'continent': '亚洲',
#   'date': '07.15',
#   'isUpdated': False,
#   'confirmAdd': 0,
#   'confirmAddCut': 0,
#   'confirm': 3227,
#   'suspect': 0,
#   'dead': 58,
#   'heal': 3091,
#   'nowConfirm': 78,
#   'confirmCompare': 0,
#   'nowConfirmCompare': 0,
#   'healCompare': 0,
#   'deadCompare': 0},
#  {'name': '尼加拉瓜',
#   'continent': '北美洲',
#   'date': '07.15',
#   'isUpdated': False,
#   'confirmAdd': 301,
#   'confirmAddCut': 0,
#   'confirm': 3147,
#   'suspect': 0,
#   'dead': 99,
#   'heal': 2282,
#   'nowConfirm': 766,
#   'confirmCompare': 301,
#   'nowConfirmCompare': 4,
#   'healCompare': 289,
#   'deadCompare': 8},
#  {'name': '索马里',
#   'continent': '非洲',
#   'date': '07.15',
#   'isUpdated': False,
#   'confirmAdd': 4,
#   'confirmAddCut': 0,
#   'confirm': 3076,
#   'suspect': 0,
#   'dead': 93,
#   'heal': 1380,
#   'nowConfirm': 1603,
#   'confirmCompare': 4,
#   'nowConfirmCompare': -33,
#   'healCompare': 37,
#   'deadCompare': 0},
#  {'name': '巴拉圭',
#   'continent': '南美洲',
#   'date': '07.15',
#   'isUpdated': False,
#   'confirmAdd': 94,
#   'confirmAddCut': 0,
#   'confirm': 3074,
#   'suspect': 0,
#   'dead': 25,
#   'heal': 1308,
#   'nowConfirm': 1741,
#   'confirmCompare': 94,
#   'nowConfirmCompare': 79,
#   'healCompare': 15,
#   'deadCompare': 0},
#  {'name': '赤道几内亚',
#   'continent': '非洲',
#   'date': '07.15',
#   'isUpdated': False,
#   'confirmAdd': 0,
#   'confirmAddCut': 0,
#   'confirm': 3071,
#   'suspect': 0,
#   'dead': 51,
#   'heal': 842,
#   'nowConfirm': 2178,
#   'confirmCompare': 0,
#   'nowConfirmCompare': 0,
#   'healCompare': 0,
#   'deadCompare': 0},
#  {'name': '马尔代夫',
#   'continent': '亚洲',
#   'date': '07.15',
#   'isUpdated': False,
#   'confirmAdd': 39,
#   'confirmAddCut': 0,
#   'confirm': 2801,
#   'suspect': 0,
#   'dead': 14,
#   'heal': 2302,
#   'nowConfirm': 485,
#   'confirmCompare': 39,
#   'nowConfirmCompare': 26,
#   'healCompare': 12,
#   'deadCompare': 1},
#  {'name': '斯里兰卡',
#   'continent': '亚洲',
#   'date': '07.15',
#   'isUpdated': False,
#   'confirmAdd': 4,
#   'confirmAddCut': 0,
#   'confirm': 2665,
#   'suspect': 0,
#   'dead': 11,
#   'heal': 1988,
#   'nowConfirm': 666,
#   'confirmCompare': 4,
#   'nowConfirmCompare': 4,
#   'healCompare': 0,
#   'deadCompare': 0},
#  {'name': '马拉维',
#   'continent': '非洲',
#   'date': '07.15',
#   'isUpdated': False,
#   'confirmAdd': 67,
#   'confirmAddCut': 0,
#   'confirm': 2497,
#   'suspect': 0,
#   'dead': 40,
#   'heal': 795,
#   'nowConfirm': 1662,
#   'confirmCompare': 67,
#   'nowConfirmCompare': 18,
#   'healCompare': 48,
#   'deadCompare': 1},
#  {'name': '黎巴嫩',
#   'continent': '亚洲',
#   'date': '07.15',
#   'isUpdated': False,
#   'confirmAdd': 32,
#   'confirmAddCut': 0,
#   'confirm': 2451,
#   'suspect': 0,
#   'dead': 37,
#   'heal': 1452,
#   'nowConfirm': 962,
#   'confirmCompare': 32,
#   'nowConfirmCompare': 2,
#   'healCompare': 29,
#   'deadCompare': 1},
#  {'name': '古巴',
#   'continent': '北美洲',
#   'date': '07.15',
#   'isUpdated': False,
#   'confirmAdd': 0,
#   'confirmAddCut': 0,
#   'confirm': 2432,
#   'suspect': 0,
#   'dead': 87,
#   'heal': 2275,
#   'nowConfirm': 70,
#   'confirmCompare': 0,
#   'nowConfirmCompare': 0,
#   'healCompare': 0,
#   'deadCompare': 0},
#  {'name': '马里',
#   'continent': '非洲',
#   'date': '07.15',
#   'isUpdated': False,
#   'confirmAdd': 0,
#   'confirmAddCut': 0,
#   'confirm': 2423,
#   'suspect': 0,
#   'dead': 121,
#   'heal': 1748,
#   'nowConfirm': 554,
#   'confirmCompare': 0,
#   'nowConfirmCompare': 0,
#   'healCompare': 0,
#   'deadCompare': 0},
#  {'name': '刚果（布）',
#   'continent': '非洲',
#   'date': '07.15',
#   'isUpdated': False,
#   'confirmAdd': 0,
#   'confirmAddCut': 0,
#   'confirm': 2028,
#   'suspect': 0,
#   'dead': 47,
#   'heal': 589,
#   'nowConfirm': 1392,
#   'confirmCompare': 0,
#   'nowConfirmCompare': 0,
#   'healCompare': 0,
#   'deadCompare': 0},
#  {'name': '爱沙尼亚',
#   'continent': '欧洲',
#   'date': '07.15',
#   'isUpdated': False,
#   'confirmAdd': 0,
#   'confirmAddCut': 0,
#   'confirm': 2015,
#   'suspect': 0,
#   'dead': 69,
#   'heal': 1897,
#   'nowConfirm': 49,
#   'confirmCompare': 0,
#   'nowConfirmCompare': 0,
#   'healCompare': 0,
#   'deadCompare': 0},
#  {'name': '斯洛伐克',
#   'continent': '欧洲',
#   'date': '07.15',
#   'isUpdated': False,
#   'confirmAdd': 0,
#   'confirmAddCut': 0,
#   'confirm': 1908,
#   'suspect': 0,
#   'dead': 28,
#   'heal': 1493,
#   'nowConfirm': 387,
#   'confirmCompare': 0,
#   'nowConfirmCompare': 0,
#   'healCompare': 0,
#   'deadCompare': 0},
#  {'name': '冰岛',
#   'continent': '欧洲',
#   'date': '07.15',
#   'isUpdated': False,
#   'confirmAdd': 0,
#   'confirmAddCut': 0,
#   'confirm': 1905,
#   'suspect': 0,
#   'dead': 10,
#   'heal': 1882,
#   'nowConfirm': 13,
#   'confirmCompare': 0,
#   'nowConfirmCompare': 0,
#   'healCompare': 0,
#   'deadCompare': 0},
#  {'name': '赞比亚',
#   'continent': '非洲',
#   'date': '07.15',
#   'isUpdated': False,
#   'confirmAdd': 0,
#   'confirmAddCut': 0,
#   'confirm': 1895,
#   'suspect': 0,
#   'dead': 42,
#   'heal': 1412,
#   'nowConfirm': 441,
#   'confirmCompare': 0,
#   'nowConfirmCompare': 0,
#   'healCompare': 0,
#   'deadCompare': 0},
#  {'name': '立陶宛',
#   'continent': '欧洲',
#   'date': '07.15',
#   'isUpdated': False,
#   'confirmAdd': 0,
#   'confirmAddCut': 0,
#   'confirm': 1875,
#   'suspect': 0,
#   'dead': 79,
#   'heal': 1571,
#   'nowConfirm': 225,
#   'confirmCompare': 0,
#   'nowConfirmCompare': 0,
#   'healCompare': 0,
#   'deadCompare': 0},
#  {'name': '斯洛文尼亚',
#   'continent': '欧洲',
#   'date': '07.15',
#   'isUpdated': False,
#   'confirmAdd': 0,
#   'confirmAddCut': 0,
#   'confirm': 1859,
#   'suspect': 0,
#   'dead': 111,
#   'heal': 1488,
#   'nowConfirm': 260,
#   'confirmCompare': 0,
#   'nowConfirmCompare': 0,
#   'healCompare': 0,
#   'deadCompare': 0},
#  {'name': '几内亚比绍',
#   'continent': '非洲',
#   'date': '07.15',
#   'isUpdated': False,
#   'confirmAdd': 0,
#   'confirmAddCut': 0,
#   'confirm': 1842,
#   'suspect': 0,
#   'dead': 26,
#   'heal': 773,
#   'nowConfirm': 1043,
#   'confirmCompare': 0,
#   'nowConfirmCompare': 0,
#   'healCompare': 0,
#   'deadCompare': 0},
#  {'name': '佛得角',
#   'continent': '非洲',
#   'date': '07.15',
#   'isUpdated': False,
#   'confirmAdd': 0,
#   'confirmAddCut': 0,
#   'confirm': 1722,
#   'suspect': 0,
#   'dead': 19,
#   'heal': 772,
#   'nowConfirm': 931,
#   'confirmCompare': 0,
#   'nowConfirmCompare': 0,
#   'healCompare': 0,
#   'deadCompare': 0},
#  {'name': '塞拉利昂',
#   'continent': '非洲',
#   'date': '07.15',
#   'isUpdated': False,
#   'confirmAdd': 9,
#   'confirmAddCut': 0,
#   'confirm': 1651,
#   'suspect': 0,
#   'dead': 64,
#   'heal': 1190,
#   'nowConfirm': 397,
#   'confirmCompare': 9,
#   'nowConfirmCompare': -7,
#   'healCompare': 15,
#   'deadCompare': 1},
#  {'name': '利比亚',
#   'continent': '非洲',
#   'date': '07.15',
#   'isUpdated': False,
#   'confirmAdd': 51,
#   'confirmAddCut': 0,
#   'confirm': 1563,
#   'suspect': 0,
#   'dead': 42,
#   'heal': 370,
#   'nowConfirm': 1151,
#   'confirmCompare': 51,
#   'nowConfirmCompare': 46,
#   'healCompare': 3,
#   'deadCompare': 2},
#  {'name': '新西兰',
#   'continent': '大洋洲',
#   'date': '07.15',
#   'isUpdated': False,
#   'confirmAdd': 2,
#   'confirmAddCut': 0,
#   'confirm': 1547,
#   'suspect': 0,
#   'dead': 22,
#   'heal': 1498,
#   'nowConfirm': 27,
#   'confirmCompare': 2,
#   'nowConfirmCompare': 2,
#   'healCompare': 0,
#   'deadCompare': 0},
#  {'name': '也门',
#   'continent': '亚洲',
#   'date': '07.15',
#   'isUpdated': False,
#   'confirmAdd': 18,
#   'confirmAddCut': 0,
#   'confirm': 1516,
#   'suspect': 0,
#   'dead': 429,
#   'heal': 685,
#   'nowConfirm': 402,
#   'confirmCompare': 18,
#   'nowConfirmCompare': 3,
#   'healCompare': 10,
#   'deadCompare': 5},
#  {'name': '斯威士兰',
#   'continent': '非洲',
#   'date': '07.15',
#   'isUpdated': False,
#   'confirmAdd': 45,
#   'confirmAddCut': 0,
#   'confirm': 1434,
#   'suspect': 0,
#   'dead': 20,
#   'heal': 695,
#   'nowConfirm': 719,
#   'confirmCompare': 45,
#   'nowConfirmCompare': 38,
#   'healCompare': 7,
#   'deadCompare': 0},
#  {'name': '卢旺达',
#   'continent': '非洲',
#   'date': '07.15',
#   'isUpdated': False,
#   'confirmAdd': 38,
#   'confirmAddCut': 0,
#   'confirm': 1416,
#   'suspect': 0,
#   'dead': 4,
#   'heal': 737,
#   'nowConfirm': 675,
#   'confirmCompare': 38,
#   'nowConfirmCompare': 11,
#   'healCompare': 27,
#   'deadCompare': 0},
#  {'name': '贝宁',
#   'continent': '非洲',
#   'date': '07.15',
#   'isUpdated': False,
#   'confirmAdd': 0,
#   'confirmAddCut': 0,
#   'confirm': 1378,
#   'suspect': 0,
#   'dead': 26,
#   'heal': 557,
#   'nowConfirm': 795,
#   'confirmCompare': 0,
#   'nowConfirmCompare': 0,
#   'healCompare': 0,
#   'deadCompare': 0},
#  {'name': '突尼斯',
#   'continent': '非洲',
#   'date': '07.15',
#   'isUpdated': False,
#   'confirmAdd': 4,
#   'confirmAddCut': 0,
#   'confirm': 1306,
#   'suspect': 0,
#   'dead': 50,
#   'heal': 1087,
#   'nowConfirm': 169,
#   'confirmCompare': 4,
#   'nowConfirmCompare': -1,
#   'healCompare': 5,
#   'deadCompare': 0},
#  {'name': '黑山',
#   'continent': '欧洲',
#   'date': '07.15',
#   'isUpdated': False,
#   'confirmAdd': 0,
#   'confirmAddCut': 0,
#   'confirm': 1287,
#   'suspect': 0,
#   'dead': 24,
#   'heal': 330,
#   'nowConfirm': 933,
#   'confirmCompare': 0,
#   'nowConfirmCompare': 0,
#   'healCompare': 0,
#   'deadCompare': 0},
#  {'name': '莫桑比克',
#   'continent': '非洲',
#   'date': '07.15',
#   'isUpdated': False,
#   'confirmAdd': 0,
#   'confirmAddCut': 0,
#   'confirm': 1268,
#   'suspect': 0,
#   'dead': 9,
#   'heal': 373,
#   'nowConfirm': 886,
#   'confirmCompare': 0,
#   'nowConfirmCompare': 0,
#   'healCompare': 0,
#   'deadCompare': 0},
#  {'name': '约旦',
#   'continent': '亚洲',
#   'date': '07.15',
#   'isUpdated': False,
#   'confirmAdd': 15,
#   'confirmAddCut': 0,
#   'confirm': 1198,
#   'suspect': 0,
#   'dead': 10,
#   'heal': 1013,
#   'nowConfirm': 175,
#   'confirmCompare': 15,
#   'nowConfirmCompare': 10,
#   'healCompare': 5,
#   'deadCompare': 0},
#  {'name': '拉脱维亚',
#   'continent': '欧洲',
#   'date': '07.15',
#   'isUpdated': False,
#   'confirmAdd': 0,
#   'confirmAddCut': 0,
#   'confirm': 1174,
#   'suspect': 0,
#   'dead': 31,
#   'heal': 1022,
#   'nowConfirm': 121,
#   'confirmCompare': 0,
#   'nowConfirmCompare': 0,
#   'healCompare': 0,
#   'deadCompare': 0},
#  {'name': '尼日尔',
#   'continent': '非洲',
#   'date': '07.15',
#   'isUpdated': False,
#   'confirmAdd': 0,
#   'confirmAddCut': 0,
#   'confirm': 1099,
#   'suspect': 0,
#   'dead': 68,
#   'heal': 992,
#   'nowConfirm': 39,
#   'confirmCompare': 0,
#   'nowConfirmCompare': 0,
#   'healCompare': 0,
#   'deadCompare': 0},
#  {'name': '津巴布韦',
#   'continent': '非洲',
#   'date': '07.15',
#   'isUpdated': False,
#   'confirmAdd': 30,
#   'confirmAddCut': 0,
#   'confirm': 1064,
#   'suspect': 0,
#   'dead': 20,
#   'heal': 343,
#   'nowConfirm': 701,
#   'confirmCompare': 30,
#   'nowConfirmCompare': 29,
#   'healCompare': 0,
#   'deadCompare': 1},
#  {'name': '乌干达',
#   'continent': '非洲',
#   'date': '07.15',
#   'isUpdated': False,
#   'confirmAdd': 0,
#   'confirmAddCut': 0,
#   'confirm': 1040,
#   'suspect': 0,
#   'dead': 0,
#   'heal': 984,
#   'nowConfirm': 56,
#   'confirmCompare': 0,
#   'nowConfirmCompare': 0,
#   'healCompare': 0,
#   'deadCompare': 0},
#  {'name': '布基纳法索',
#   'continent': '非洲',
#   'date': '07.15',
#   'isUpdated': False,
#   'confirmAdd': 0,
#   'confirmAddCut': 0,
#   'confirm': 1037,
#   'suspect': 0,
#   'dead': 53,
#   'heal': 873,
#   'nowConfirm': 111,
#   'confirmCompare': 0,
#   'nowConfirmCompare': 0,
#   'healCompare': 0,
#   'deadCompare': 0},
#  {'name': '利比里亚',
#   'continent': '非洲',
#   'date': '07.15',
#   'isUpdated': False,
#   'confirmAdd': 0,
#   'confirmAddCut': 0,
#   'confirm': 1024,
#   'suspect': 0,
#   'dead': 51,
#   'heal': 439,
#   'nowConfirm': 534,
#   'confirmCompare': 0,
#   'nowConfirmCompare': 0,
#   'healCompare': 0,
#   'deadCompare': 0},
#  {'name': '塞浦路斯',
#   'continent': '亚洲',
#   'date': '07.15',
#   'isUpdated': False,
#   'confirmAdd': 0,
#   'confirmAddCut': 0,
#   'confirm': 1023,
#   'suspect': 0,
#   'dead': 19,
#   'heal': 839,
#   'nowConfirm': 165,
#   'confirmCompare': 0,
#   'nowConfirmCompare': 0,
#   'healCompare': 0,
#   'deadCompare': 0},
#  {'name': '格鲁吉亚',
#   'continent': '亚洲',
#   'date': '07.15',
#   'isUpdated': False,
#   'confirmAdd': 0,
#   'confirmAddCut': 0,
#   'confirm': 999,
#   'suspect': 0,
#   'dead': 15,
#   'heal': 870,
#   'nowConfirm': 114,
#   'confirmCompare': 0,
#   'nowConfirmCompare': 0,
#   'healCompare': 0,
#   'deadCompare': 0},
#  {'name': '乌拉圭',
#   'continent': '南美洲',
#   'date': '07.15',
#   'isUpdated': False,
#   'confirmAdd': 8,
#   'confirmAddCut': 0,
#   'confirm': 997,
#   'suspect': 0,
#   'dead': 31,
#   'heal': 905,
#   'nowConfirm': 61,
#   'confirmCompare': 8,
#   'nowConfirmCompare': 6,
#   'healCompare': 2,
#   'deadCompare': 0},
#  {'name': '乍得',
#   'continent': '非洲',
#   'date': '07.15',
#   'isUpdated': False,
#   'confirmAdd': 4,
#   'confirmAddCut': 0,
#   'confirm': 884,
#   'suspect': 0,
#   'dead': 75,
#   'heal': 798,
#   'nowConfirm': 11,
#   'confirmCompare': 4,
#   'nowConfirmCompare': -2,
#   'healCompare': 6,
#   'deadCompare': 0},
#  {'name': '纳米比亚',
#   'continent': '非洲',
#   'date': '07.15',
#   'isUpdated': False,
#   'confirmAdd': 0,
#   'confirmAddCut': 0,
#   'confirm': 864,
#   'suspect': 0,
#   'dead': 2,
#   'heal': 29,
#   'nowConfirm': 833,
#   'confirmCompare': 0,
#   'nowConfirmCompare': 0,
#   'healCompare': 0,
#   'deadCompare': 0},
#  {'name': '安道尔',
#   'continent': '欧洲',
#   'date': '07.15',
#   'isUpdated': False,
#   'confirmAdd': 3,
#   'confirmAddCut': 0,
#   'confirm': 861,
#   'suspect': 0,
#   'dead': 52,
#   'heal': 803,
#   'nowConfirm': 6,
#   'confirmCompare': 3,
#   'nowConfirmCompare': 3,
#   'healCompare': 0,
#   'deadCompare': 0},
#  {'name': '苏里南',
#   'continent': '南美洲',
#   'date': '07.15',
#   'isUpdated': False,
#   'confirmAdd': 21,
#   'confirmAddCut': 0,
#   'confirm': 801,
#   'suspect': 0,
#   'dead': 18,
#   'heal': 543,
#   'nowConfirm': 240,
#   'confirmCompare': 21,
#   'nowConfirmCompare': 4,
#   'healCompare': 17,
#   'deadCompare': 0},
#  {'name': '牙买加',
#   'continent': '北美洲',
#   'date': '07.15',
#   'isUpdated': False,
#   'confirmAdd': 3,
#   'confirmAddCut': 0,
#   'confirm': 762,
#   'suspect': 0,
#   'dead': 10,
#   'heal': 643,
#   'nowConfirm': 109,
#   'confirmCompare': 3,
#   'nowConfirmCompare': -12,
#   'healCompare': 15,
#   'deadCompare': 0},
#  {'name': '多哥',
#   'continent': '非洲',
#   'date': '07.15',
#   'isUpdated': False,
#   'confirmAdd': 10,
#   'confirmAddCut': 0,
#   'confirm': 731,
#   'suspect': 0,
#   'dead': 15,
#   'heal': 528,
#   'nowConfirm': 188,
#   'confirmCompare': 10,
#   'nowConfirmCompare': -1,
#   'healCompare': 11,
#   'deadCompare': 0},
#  {'name': '钻石号邮轮',
#   'continent': '其他',
#   'date': '07.15',
#   'isUpdated': False,
#   'confirmAdd': 0,
#   'confirmAddCut': 0,
#   'confirm': 712,
#   'suspect': 0,
#   'dead': 13,
#   'heal': 651,
#   'nowConfirm': 48,
#   'confirmCompare': 0,
#   'nowConfirmCompare': 0,
#   'healCompare': 0,
#   'deadCompare': 0},
#  {'name': '圣马力诺',
#   'continent': '欧洲',
#   'date': '07.15',
#   'isUpdated': False,
#   'confirmAdd': 0,
#   'confirmAddCut': 0,
#   'confirm': 699,
#   'suspect': 0,
#   'dead': 42,
#   'heal': 656,
#   'nowConfirm': 1,
#   'confirmCompare': 0,
#   'nowConfirmCompare': 0,
#   'healCompare': 0,
#   'deadCompare': 0},
#  {'name': '马耳他',
#   'continent': '欧洲',
#   'date': '07.15',
#   'isUpdated': False,
#   'confirmAdd': 0,
#   'confirmAddCut': 0,
#   'confirm': 674,
#   'suspect': 0,
#   'dead': 9,
#   'heal': 660,
#   'nowConfirm': 5,
#   'confirmCompare': 0,
#   'nowConfirmCompare': 0,
#   'healCompare': 0,
#   'deadCompare': 0},
#  {'name': '安哥拉',
#   'continent': '非洲',
#   'date': '07.15',
#   'isUpdated': False,
#   'confirmAdd': 16,
#   'confirmAddCut': 0,
#   'confirm': 541,
#   'suspect': 0,
#   'dead': 26,
#   'heal': 118,
#   'nowConfirm': 397,
#   'confirmCompare': 16,
#   'nowConfirmCompare': 16,
#   'healCompare': 0,
#   'deadCompare': 0},
#  {'name': '坦桑尼亚',
#   'continent': '非洲',
#   'date': '07.15',
#   'isUpdated': False,
#   'confirmAdd': 0,
#   'confirmAddCut': 0,
#   'confirm': 509,
#   'suspect': 0,
#   'dead': 21,
#   'heal': 183,
#   'nowConfirm': 305,
#   'confirmCompare': 0,
#   'nowConfirmCompare': 0,
#   'healCompare': 0,
#   'deadCompare': 0},
#  {'name': '叙利亚',
#   'continent': '亚洲',
#   'date': '07.15',
#   'isUpdated': False,
#   'confirmAdd': 0,
#   'confirmAddCut': 0,
#   'confirm': 439,
#   'suspect': 0,
#   'dead': 21,
#   'heal': 138,
#   'nowConfirm': 280,
#   'confirmCompare': 0,
#   'nowConfirmCompare': 0,
#   'healCompare': 0,
#   'deadCompare': 0},
#  {'name': '博茨瓦纳',
#   'continent': '非洲',
#   'date': '07.15',
#   'isUpdated': False,
#   'confirmAdd': 0,
#   'confirmAddCut': 0,
#   'confirm': 399,
#   'suspect': 0,
#   'dead': 1,
#   'heal': 38,
#   'nowConfirm': 360,
#   'confirmCompare': 0,
#   'nowConfirmCompare': 0,
#   'healCompare': 0,
#   'deadCompare': 0},
#  {'name': '越南',
#   'continent': '亚洲',
#   'date': '07.15',
#   'isUpdated': False,
#   'confirmAdd': 0,
#   'confirmAddCut': 0,
#   'confirm': 373,
#   'suspect': 0,
#   'dead': 0,
#   'heal': 352,
#   'nowConfirm': 21,
#   'confirmCompare': 0,
#   'nowConfirmCompare': 0,
#   'healCompare': 0,
#   'deadCompare': 0},
#  {'name': '毛里求斯',
#   'continent': '非洲',
#   'date': '07.15',
#   'isUpdated': False,
#   'confirmAdd': 0,
#   'confirmAddCut': 0,
#   'confirm': 342,
#   'suspect': 0,
#   'dead': 10,
#   'heal': 330,
#   'nowConfirm': 2,
#   'confirmCompare': 0,
#   'nowConfirmCompare': 0,
#   'healCompare': 0,
#   'deadCompare': 0},
#  {'name': '缅甸',
#   'continent': '亚洲',
#   'date': '07.15',
#   'isUpdated': False,
#   'confirmAdd': 0,
#   'confirmAddCut': 0,
#   'confirm': 337,
#   'suspect': 0,
#   'dead': 6,
#   'heal': 261,
#   'nowConfirm': 70,
#   'confirmCompare': 0,
#   'nowConfirmCompare': 0,
#   'healCompare': 0,
#   'deadCompare': 0},
#  {'name': '科摩罗',
#   'continent': '非洲',
#   'date': '07.15',
#   'isUpdated': False,
#   'confirmAdd': 4,
#   'confirmAddCut': 0,
#   'confirm': 321,
#   'suspect': 0,
#   'dead': 7,
#   'heal': 302,
#   'nowConfirm': 12,
#   'confirmCompare': 4,
#   'nowConfirmCompare': -2,
#   'healCompare': 6,
#   'deadCompare': 0},
#  {'name': '圭亚那',
#   'continent': '南美洲',
#   'date': '07.15',
#   'isUpdated': False,
#   'confirmAdd': 8,
#   'confirmAddCut': 0,
#   'confirm': 308,
#   'suspect': 0,
#   'dead': 17,
#   'heal': 156,
#   'nowConfirm': 135,
#   'confirmCompare': 8,
#   'nowConfirmCompare': 7,
#   'healCompare': 1,
#   'deadCompare': 0},
#  {'name': '布隆迪',
#   'continent': '非洲',
#   'date': '07.15',
#   'isUpdated': False,
#   'confirmAdd': 0,
#   'confirmAddCut': 0,
#   'confirm': 269,
#   'suspect': 0,
#   'dead': 1,
#   'heal': 207,
#   'nowConfirm': 61,
#   'confirmCompare': 0,
#   'nowConfirmCompare': 0,
#   'healCompare': 0,
#   'deadCompare': 0},
#  {'name': '莱索托',
#   'continent': '非洲',
#   'date': '07.15',
#   'isUpdated': False,
#   'confirmAdd': 0,
#   'confirmAddCut': 0,
#   'confirm': 256,
#   'suspect': 0,
#   'dead': 3,
#   'heal': 48,
#   'nowConfirm': 205,
#   'confirmCompare': 0,
#   'nowConfirmCompare': 0,
#   'healCompare': 0,
#   'deadCompare': 0},
#  {'name': '蒙古',
#   'continent': '亚洲',
#   'date': '07.15',
#   'isUpdated': False,
#   'confirmAdd': 0,
#   'confirmAddCut': 0,
#   'confirm': 243,
#   'suspect': 0,
#   'dead': 0,
#   'heal': 204,
#   'nowConfirm': 39,
#   'confirmCompare': 0,
#   'nowConfirmCompare': 0,
#   'healCompare': 0,
#   'deadCompare': 0},
#  {'name': '厄立特里亚',
#   'continent': '非洲',
#   'date': '07.15',
#   'isUpdated': False,
#   'confirmAdd': 0,
#   'confirmAddCut': 0,
#   'confirm': 232,
#   'suspect': 0,
#   'dead': 0,
#   'heal': 107,
#   'nowConfirm': 125,
#   'confirmCompare': 0,
#   'nowConfirmCompare': 0,
#   'healCompare': 0,
#   'deadCompare': 0},
#  {'name': '柬埔寨',
#   'continent': '亚洲',
#   'date': '07.15',
#   'isUpdated': False,
#   'confirmAdd': 0,
#   'confirmAddCut': 0,
#   'confirm': 165,
#   'suspect': 0,
#   'dead': 0,
#   'heal': 133,
#   'nowConfirm': 32,
#   'confirmCompare': 0,
#   'nowConfirmCompare': 0,
#   'healCompare': 0,
#   'deadCompare': 0},
#  {'name': '文莱',
#   'continent': '亚洲',
#   'date': '07.15',
#   'isUpdated': False,
#   'confirmAdd': 0,
#   'confirmAddCut': 0,
#   'confirm': 141,
#   'suspect': 0,
#   'dead': 3,
#   'heal': 138,
#   'nowConfirm': 0,
#   'confirmCompare': 0,
#   'nowConfirmCompare': 0,
#   'healCompare': 0,
#   'deadCompare': 0},
#  {'name': '特立尼达和多巴哥',
#   'continent': '',
#   'date': '07.15',
#   'isUpdated': False,
#   'confirmAdd': 0,
#   'confirmAddCut': 0,
#   'confirm': 133,
#   'suspect': 0,
#   'dead': 8,
#   'heal': 124,
#   'nowConfirm': 1,
#   'confirmCompare': 0,
#   'nowConfirmCompare': 0,
#   'healCompare': 0,
#   'deadCompare': 0},
#  {'name': '巴哈马',
#   'continent': '北美洲',
#   'date': '07.15',
#   'isUpdated': False,
#   'confirmAdd': 3,
#   'confirmAddCut': 0,
#   'confirm': 116,
#   'suspect': 0,
#   'dead': 11,
#   'heal': 91,
#   'nowConfirm': 14,
#   'confirmCompare': 3,
#   'nowConfirmCompare': 3,
#   'healCompare': 0,
#   'deadCompare': 0},
#  {'name': '摩纳哥',
#   'continent': '欧洲',
#   'date': '07.15',
#   'isUpdated': False,
#   'confirmAdd': 0,
#   'confirmAddCut': 0,
#   'confirm': 109,
#   'suspect': 0,
#   'dead': 4,
#   'heal': 97,
#   'nowConfirm': 8,
#   'confirmCompare': 0,
#   'nowConfirmCompare': 0,
#   'healCompare': 0,
#   'deadCompare': 0},
#  {'name': '巴巴多斯',
#   'continent': '北美洲',
#   'date': '07.15',
#   'isUpdated': False,
#   'confirmAdd': 0,
#   'confirmAddCut': 0,
#   'confirm': 103,
#   'suspect': 0,
#   'dead': 7,
#   'heal': 90,
#   'nowConfirm': 6,
#   'confirmCompare': 0,
#   'nowConfirmCompare': 0,
#   'healCompare': 0,
#   'deadCompare': 0},
#  {'name': '塞舌尔',
#   'continent': '非洲',
#   'date': '07.15',
#   'isUpdated': False,
#   'confirmAdd': 0,
#   'confirmAddCut': 0,
#   'confirm': 100,
#   'suspect': 0,
#   'dead': 0,
#   'heal': 11,
#   'nowConfirm': 89,
#   'confirmCompare': 0,
#   'nowConfirmCompare': 0,
#   'healCompare': 0,
#   'deadCompare': 0},
#  {'name': '列支敦士登公国',
#   'continent': '欧洲',
#   'date': '07.15',
#   'isUpdated': False,
#   'confirmAdd': 0,
#   'confirmAddCut': 0,
#   'confirm': 84,
#   'suspect': 0,
#   'dead': 1,
#   'heal': 81,
#   'nowConfirm': 2,
#   'confirmCompare': 0,
#   'nowConfirmCompare': 0,
#   'healCompare': 0,
#   'deadCompare': 0},
#  {'name': '不丹',
#   'continent': '亚洲',
#   'date': '07.15',
#   'isUpdated': False,
#   'confirmAdd': 0,
#   'confirmAddCut': 0,
#   'confirm': 84,
#   'suspect': 0,
#   'dead': 0,
#   'heal': 78,
#   'nowConfirm': 6,
#   'confirmCompare': 0,
#   'nowConfirmCompare': 0,
#   'healCompare': 0,
#   'deadCompare': 0},
#  {'name': '安提瓜和巴布达',
#   'continent': '北美洲',
#   'date': '07.15',
#   'isUpdated': False,
#   'confirmAdd': 0,
#   'confirmAddCut': 0,
#   'confirm': 74,
#   'suspect': 0,
#   'dead': 3,
#   'heal': 57,
#   'nowConfirm': 14,
#   'confirmCompare': 0,
#   'nowConfirmCompare': 0,
#   'healCompare': 0,
#   'deadCompare': 0},
#  {'name': '冈比亚',
#   'continent': '非洲',
#   'date': '07.15',
#   'isUpdated': False,
#   'confirmAdd': 0,
#   'confirmAddCut': 0,
#   'confirm': 64,
#   'suspect': 0,
#   'dead': 3,
#   'heal': 34,
#   'nowConfirm': 27,
#   'confirmCompare': 0,
#   'nowConfirmCompare': 0,
#   'healCompare': 0,
#   'deadCompare': 0},
#  {'name': '伯利兹',
#   'continent': '北美洲',
#   'date': '07.15',
#   'isUpdated': False,
#   'confirmAdd': 2,
#   'confirmAddCut': 0,
#   'confirm': 39,
#   'suspect': 0,
#   'dead': 2,
#   'heal': 21,
#   'nowConfirm': 16,
#   'confirmCompare': 2,
#   'nowConfirmCompare': 1,
#   'healCompare': 1,
#   'deadCompare': 0},
#  {'name': '马提尼克岛',
#   'continent': '北美洲',
#   'date': '03.23',
#   'isUpdated': False,
#   'confirmAdd': 0,
#   'confirmAddCut': 0,
#   'confirm': 37,
#   'suspect': 0,
#   'dead': 1,
#   'heal': 0,
#   'nowConfirm': 36,
#   'confirmCompare': 0,
#   'nowConfirmCompare': 0,
#   'healCompare': 0,
#   'deadCompare': 0},
#  {'name': '圣文森特和格林纳丁斯',
#   'continent': '北美洲',
#   'date': '07.15',
#   'isUpdated': False,
#   'confirmAdd': 0,
#   'confirmAddCut': 0,
#   'confirm': 35,
#   'suspect': 0,
#   'dead': 0,
#   'heal': 29,
#   'nowConfirm': 6,
#   'confirmCompare': 0,
#   'nowConfirmCompare': 0,
#   'healCompare': 0,
#   'deadCompare': 0},
#  {'name': '斐济',
#   'continent': '大洋洲',
#   'date': '07.15',
#   'isUpdated': False,
#   'confirmAdd': 0,
#   'confirmAddCut': 0,
#   'confirm': 26,
#   'suspect': 0,
#   'dead': 0,
#   'heal': 18,
#   'nowConfirm': 8,
#   'confirmCompare': 0,
#   'nowConfirmCompare': 0,
#   'healCompare': 0,
#   'deadCompare': 0},
#  {'name': '东帝汶',
#   'continent': '亚洲',
#   'date': '07.15',
#   'isUpdated': False,
#   'confirmAdd': 0,
#   'confirmAddCut': 0,
#   'confirm': 24,
#   'suspect': 0,
#   'dead': 0,
#   'heal': 24,
#   'nowConfirm': 0,
#   'confirmCompare': 0,
#   'nowConfirmCompare': 0,
#   'healCompare': 0,
#   'deadCompare': 0},
#  {'name': '格林纳达',
#   'continent': '北美洲',
#   'date': '07.15',
#   'isUpdated': False,
#   'confirmAdd': 0,
#   'confirmAddCut': 0,
#   'confirm': 23,
#   'suspect': 0,
#   'dead': 0,
#   'heal': 23,
#   'nowConfirm': 0,
#   'confirmCompare': 0,
#   'nowConfirmCompare': 0,
#   'healCompare': 0,
#   'deadCompare': 0},
#  {'name': '圣卢西亚',
#   'continent': '北美洲',
#   'date': '07.15',
#   'isUpdated': False,
#   'confirmAdd': 0,
#   'confirmAddCut': 0,
#   'confirm': 22,
#   'suspect': 0,
#   'dead': 0,
#   'heal': 19,
#   'nowConfirm': 3,
#   'confirmCompare': 0,
#   'nowConfirmCompare': 0,
#   'healCompare': 0,
#   'deadCompare': 0},
#  {'name': '老挝',
#   'continent': '亚洲',
#   'date': '07.15',
#   'isUpdated': False,
#   'confirmAdd': 0,
#   'confirmAddCut': 0,
#   'confirm': 19,
#   'suspect': 0,
#   'dead': 0,
#   'heal': 19,
#   'nowConfirm': 0,
#   'confirmCompare': 0,
#   'nowConfirmCompare': 0,
#   'healCompare': 0,
#   'deadCompare': 0},
#  {'name': '多米尼克',
#   'continent': '北美洲',
#   'date': '07.15',
#   'isUpdated': False,
#   'confirmAdd': 0,
#   'confirmAddCut': 0,
#   'confirm': 18,
#   'suspect': 0,
#   'dead': 0,
#   'heal': 18,
#   'nowConfirm': 0,
#   'confirmCompare': 0,
#   'nowConfirmCompare': 0,
#   'healCompare': 0,
#   'deadCompare': 0},
#  {'name': '圣基茨和尼维斯',
#   'continent': '北美洲',
#   'date': '07.15',
#   'isUpdated': False,
#   'confirmAdd': 0,
#   'confirmAddCut': 0,
#   'confirm': 17,
#   'suspect': 0,
#   'dead': 0,
#   'heal': 15,
#   'nowConfirm': 2,
#   'confirmCompare': 0,
#   'nowConfirmCompare': 0,
#   'healCompare': 0,
#   'deadCompare': 0},
#  {'name': '梵蒂冈',
#   'continent': '欧洲',
#   'date': '07.15',
#   'isUpdated': False,
#   'confirmAdd': 0,
#   'confirmAddCut': 0,
#   'confirm': 12,
#   'suspect': 0,
#   'dead': 0,
#   'heal': 12,
#   'nowConfirm': 0,
#   'confirmCompare': 0,
#   'nowConfirmCompare': 0,
#   'healCompare': 0,
#   'deadCompare': 0},
#  {'name': '巴布亚新几内亚',
#   'continent': '大洋洲',
#   'date': '07.15',
#   'isUpdated': False,
#   'confirmAdd': 0,
#   'confirmAddCut': 0,
#   'confirm': 11,
#   'suspect': 0,
#   'dead': 0,
#   'heal': 8,
#   'nowConfirm': 3,
#   'confirmCompare': 0,
#   'nowConfirmCompare': 0,
#   'healCompare': 0,
#   'deadCompare': 0}]

# %% [markdown]
# # 外国部分国家历史每日数据

# %%
# url6 = "https://api.inews.qq.com/newsqa/v1/automation/foreign/daily/list?country="

# 这里就会用到data5，其中name字段就是国家名
country_list = [c['name'] for c in data5] # 获取国家列表
for i in country_list:  
    # 请求每个国家的数据，这里并不是所有的国家都有统计每日数据
    # 因此最终只能得到部分国家的数据
    res6 = requests.get(url6+i, headers=headers2) 
    data6 = res6.json()['data'] # 提取具体数据
    
    if data6: # 当该国有数据的时候就存储下来
        # 可直接存储数据
        df_to_csv(pd.DataFrame(data6), filepath_fg+'/部分国家历史每日数据', f'{i}.csv')
        print(f"{i} 每日数据爬取OK")
    
    # 这里由于频繁请求，怕被封因此睡眠1秒
    time.sleep(1)
# Out:
# 美国 每日数据爬取OK
# 巴西 每日数据爬取OK
# 印度 每日数据爬取OK
# 俄罗斯 每日数据爬取OK
# 秘鲁 每日数据爬取OK
# 智利 每日数据爬取OK
# 墨西哥 每日数据爬取OK
# 西班牙 每日数据爬取OK
# 南非 每日数据爬取OK
# 英国 每日数据爬取OK
# 伊朗 每日数据爬取OK
# 巴基斯坦 每日数据爬取OK
# 意大利 每日数据爬取OK
# 沙特阿拉伯 每日数据爬取OK
# 土耳其 每日数据爬取OK
# 法国 每日数据爬取OK
# 德国 每日数据爬取OK
# 孟加拉 每日数据爬取OK
# 哥伦比亚 每日数据爬取OK
# 加拿大 每日数据爬取OK
# 阿根廷 每日数据爬取OK
# 卡塔尔 每日数据爬取OK
# 埃及 每日数据爬取OK
# 伊拉克 每日数据爬取OK
# 印度尼西亚 每日数据爬取OK
# 瑞典 每日数据爬取OK
# 厄瓜多尔 每日数据爬取OK
# 白俄罗斯 每日数据爬取OK
# 比利时 每日数据爬取OK
# 哈萨克斯坦 每日数据爬取OK
# 阿曼 每日数据爬取OK
# 菲律宾 每日数据爬取OK
# 科威特 每日数据爬取OK
# 乌克兰 每日数据爬取OK
# 阿联酋 每日数据爬取OK
# 荷兰 每日数据爬取OK
# 玻利维亚 每日数据爬取OK
# 巴拿马 每日数据爬取OK
# 葡萄牙 每日数据爬取OK
# 新加坡 每日数据爬取OK
# 多米尼加 每日数据爬取OK
# 以色列 每日数据爬取OK
# 波兰 每日数据爬取OK
# 阿富汗 每日数据爬取OK
# 巴林 每日数据爬取OK
# 尼日利亚 每日数据爬取OK
# 罗马尼亚 每日数据爬取OK
# 瑞士 每日数据爬取OK
# 亚美尼亚 每日数据爬取OK
# 危地马拉 每日数据爬取OK
# 洪都拉斯 每日数据爬取OK
# 爱尔兰 每日数据爬取OK
# 阿塞拜疆 每日数据爬取OK
# 加纳 每日数据爬取OK
# 日本本土 每日数据爬取OK
# 阿尔及利亚 每日数据爬取OK
# 摩尔多瓦 每日数据爬取OK
# 奥地利 每日数据爬取OK
# 塞尔维亚 每日数据爬取OK
# 尼泊尔 每日数据爬取OK
# 摩洛哥 每日数据爬取OK
# 喀麦隆 每日数据爬取OK
# 乌兹别克斯坦 每日数据爬取OK
# 韩国 每日数据爬取OK
# 捷克 每日数据爬取OK
# 丹麦 每日数据爬取OK
# 科特迪瓦 每日数据爬取OK
# 吉尔吉斯斯坦 每日数据爬取OK
# 肯尼亚 每日数据爬取OK
# 澳大利亚 每日数据爬取OK
# 苏丹 每日数据爬取OK
# 萨尔瓦多 每日数据爬取OK
# 委内瑞拉 每日数据爬取OK
# 挪威 每日数据爬取OK
# 马来西亚 每日数据爬取OK
# 哥斯达黎加 每日数据爬取OK
# 北马其顿 每日数据爬取OK
# 塞内加尔 每日数据爬取OK
# 刚果（金） 每日数据爬取OK
# 埃塞俄比亚 每日数据爬取OK
# 保加利亚 每日数据爬取OK
# 芬兰 每日数据爬取OK
# 波黑 每日数据爬取OK
# 巴勒斯坦 每日数据爬取OK
# 海地 每日数据爬取OK
# 塔吉克斯坦 每日数据爬取OK
# 几内亚 每日数据爬取OK
# 加蓬 每日数据爬取OK
# 毛里塔尼亚 每日数据爬取OK
# 马达加斯加 每日数据爬取OK
# 卢森堡 每日数据爬取OK
# 吉布提 每日数据爬取OK
# 中非共和国 每日数据爬取OK
# 匈牙利 每日数据爬取OK
# 希腊 每日数据爬取OK
# 克罗地亚 每日数据爬取OK
# 阿尔巴尼亚 每日数据爬取OK
# 泰国 每日数据爬取OK
# 尼加拉瓜 每日数据爬取OK
# 索马里 每日数据爬取OK
# 巴拉圭 每日数据爬取OK
# 赤道几内亚 每日数据爬取OK
# 马尔代夫 每日数据爬取OK
# 斯里兰卡 每日数据爬取OK
# 马拉维 每日数据爬取OK
# 黎巴嫩 每日数据爬取OK
# 古巴 每日数据爬取OK
# 马里 每日数据爬取OK
# 刚果（布） 每日数据爬取OK
# 爱沙尼亚 每日数据爬取OK
# 斯洛伐克 每日数据爬取OK
# 冰岛 每日数据爬取OK
# 赞比亚 每日数据爬取OK
# 立陶宛 每日数据爬取OK
# 斯洛文尼亚 每日数据爬取OK
# 几内亚比绍 每日数据爬取OK
# 佛得角 每日数据爬取OK
# 塞拉利昂 每日数据爬取OK
# 利比亚 每日数据爬取OK
# 新西兰 每日数据爬取OK
# 也门 每日数据爬取OK
# 斯威士兰 每日数据爬取OK
# 卢旺达 每日数据爬取OK
# 贝宁 每日数据爬取OK
# 突尼斯 每日数据爬取OK
# 黑山 每日数据爬取OK
# 莫桑比克 每日数据爬取OK
# 约旦 每日数据爬取OK
# 拉脱维亚 每日数据爬取OK
# 尼日尔 每日数据爬取OK
# 津巴布韦 每日数据爬取OK
# 乌干达 每日数据爬取OK
# 布基纳法索 每日数据爬取OK
# 利比里亚 每日数据爬取OK
# 塞浦路斯 每日数据爬取OK
# 格鲁吉亚 每日数据爬取OK
# 乌拉圭 每日数据爬取OK
# 乍得 每日数据爬取OK
# 纳米比亚 每日数据爬取OK
# 安道尔 每日数据爬取OK
# 苏里南 每日数据爬取OK
# 牙买加 每日数据爬取OK
# 多哥 每日数据爬取OK
# 钻石号邮轮 每日数据爬取OK
# 圣马力诺 每日数据爬取OK
# 马耳他 每日数据爬取OK
# 安哥拉 每日数据爬取OK
# 坦桑尼亚 每日数据爬取OK
# 叙利亚 每日数据爬取OK
# 博茨瓦纳 每日数据爬取OK
# 越南 每日数据爬取OK
# 毛里求斯 每日数据爬取OK
# 缅甸 每日数据爬取OK
# 科摩罗 每日数据爬取OK
# 圭亚那 每日数据爬取OK
# 布隆迪 每日数据爬取OK
# 莱索托 每日数据爬取OK
# 蒙古 每日数据爬取OK
# 厄立特里亚 每日数据爬取OK
# 柬埔寨 每日数据爬取OK
# 文莱 每日数据爬取OK
# 特立尼达和多巴哥 每日数据爬取OK
# 巴哈马 每日数据爬取OK
# 摩纳哥 每日数据爬取OK
# 巴巴多斯 每日数据爬取OK
# 塞舌尔 每日数据爬取OK
# 列支敦士登公国 每日数据爬取OK
# 不丹 每日数据爬取OK
# 安提瓜和巴布达 每日数据爬取OK
# 冈比亚 每日数据爬取OK
# 伯利兹 每日数据爬取OK
# 马提尼克岛 每日数据爬取OK
# 圣文森特和格林纳丁斯 每日数据爬取OK
# 斐济 每日数据爬取OK
# 东帝汶 每日数据爬取OK
# 格林纳达 每日数据爬取OK
# 圣卢西亚 每日数据爬取OK
# 老挝 每日数据爬取OK
# 多米尼克 每日数据爬取OK
# 圣基茨和尼维斯 每日数据爬取OK
# 梵蒂冈 每日数据爬取OK
# 巴布亚新几内亚 每日数据爬取OK

# %% [markdown]
# # 国内具体省市的每日数据

# %%
# url7 = "https://api.inews.qq.com/newsqa/v1/query/pubished/daily/list?province="
filepath_cn = "./疫情数据/国内数据"
provinces = ['安徽', '澳门', '香港', '北京', '福建', '甘肃', '广东', '广西', '贵州', '海南', '河北', '河南', '黑龙江', '湖北', '湖南', '吉林', '江苏', '江西', '辽宁', '内蒙古', '宁夏', '青海', '山东', '山西', '陕西', '上海', '四川', '台湾', '天津', '西藏', '香港', '新疆', '云南', '浙江', '重庆']
for p in provinces:
    res7 = requests.get(url7+p, headers=headers2)
    data7 = res7.json()['data'] # 提取具体数据
    
    df_to_csv(pd.DataFrame(data7), filepath_cn+'/各省每日数据', f'{p}.csv')
    print(f"{p} 每日数据爬取OK")
    
    # 这里由于频繁请求，怕被封因此睡眠1秒
    time.sleep(1)
# Out:
# 安徽 每日数据爬取OK
# 澳门 每日数据爬取OK
# 香港 每日数据爬取OK
# 北京 每日数据爬取OK
# 福建 每日数据爬取OK
# 甘肃 每日数据爬取OK
# 广东 每日数据爬取OK
# 广西 每日数据爬取OK
# 贵州 每日数据爬取OK
# 海南 每日数据爬取OK
# 河北 每日数据爬取OK
# 河南 每日数据爬取OK
# 黑龙江 每日数据爬取OK
# 湖北 每日数据爬取OK
# 湖南 每日数据爬取OK
# 吉林 每日数据爬取OK
# 江苏 每日数据爬取OK
# 江西 每日数据爬取OK
# 辽宁 每日数据爬取OK
# 内蒙古 每日数据爬取OK
# 宁夏 每日数据爬取OK
# 青海 每日数据爬取OK
# 山东 每日数据爬取OK
# 山西 每日数据爬取OK
# 陕西 每日数据爬取OK
# 上海 每日数据爬取OK
# 四川 每日数据爬取OK
# 台湾 每日数据爬取OK
# 天津 每日数据爬取OK
# 西藏 每日数据爬取OK
# 香港 每日数据爬取OK
# 新疆 每日数据爬取OK
# 云南 每日数据爬取OK
# 浙江 每日数据爬取OK
# 重庆 每日数据爬取OK
